# %%
# %reset -f

# %%
import pandas as pd
from sssom.parsers import parse_sssom_table
from sssom import compare_dataframes
from sssom.parsers import split_dataframe
from sssom.util import MappingSetDataFrame
from os.path import join
from oaklib import OntologyResource
from oaklib.implementations import SqlImplementation
import textdistance

# %%
lexmatch_file = "../mappings/mondo-sources-all-lexical.sssom.tsv"
mondo_sssom = "../ontology/tmp/mondo.sssom.tsv"
dir_name = "dataframes"
exclusion_files = [
    "../ontology/reports/doid_term_exclusions.txt",
    "../ontology/reports/omim_term_exclusions.txt",
    "../ontology/reports/ordo_term_exclusions.txt",   
    "../ontology/reports/ncit_term_exclusions.txt",
    "../ontology/reports/icd10cm_term_exclusions.txt"
]

# %%
# Functions

def add_distance(df, col_name, txt_dist_pkg):
    df\
    .insert(\
            len(df.columns),\
            col_name,\
            df.apply\
            (\
                lambda x: txt_dist_pkg\
                 (\
                    x.subject_label.lower(), x.object_label.lower()\
                    if pd.notnull(x.object_label) else "99"\
                 ),\
                axis=1,\
            )\
           )

def print_prefixes(df):
    object_prefixes = df['object_id'].str.split(':').apply(lambda x: x[0] ).drop_duplicates()
    subject_prefixes = df['subject_id'].str.split(':').apply(lambda x: x[0] ).drop_duplicates()
    predicate_ids = df['predicate_id'].drop_duplicates()
    

    print(f"subject_prefixes:\n {subject_prefixes} \n \
          object_prefixes:\n {object_prefixes} \n \
          predicate_ids:\n {predicate_ids} ")

    
def flip_predicate(predicate_id):
    flip_dict = {
        "skos:closeMatch": "skos:closeMatch",
        "skos:relatedMatch": "skos:relatedMatch",
        "skos:narrowMatch" : "skos:broadMatch",
        "skos:broadMatch" : "skos:narrowMatch",
        "skos:exactMatch" : "skos:exactMatch"
    }
    
    return flip_dict[predicate_id]

def compare_and_comment_df(mondo_df, lex_df):
    df = compare_dataframes(mondo_df, lex_df).combined_dataframe
    df['comment'] = df['comment'].str.replace('UNIQUE_1', "MONDO_MAPPINGS")
    df['comment'] = df['comment'].str.replace('UNIQUE_2', "LEXMATCH")
    return df

def get_unmapped_df(comparison_df):
#     mappings = ["LEXMATCH", "MONDO_MAPPINGS"]
#     unmapped_df = comparison_df[
#         (comparison_df['comment'].str.contains("|".join(mappings)))
#     ]
    unmapped_lex_df = comparison_df[
        comparison_df['object_id'].str.contains("|".join(in_lex_but_not_mondo_list)) &
        comparison_df['comment'].str.contains("LEXMATCH")
    ]
    
    unmapped_mondo_df = comparison_df[
        comparison_df['object_id'].str.contains("|".join(in_mondo_but_not_lex_list)) &
        comparison_df['comment'].str.contains("MONDO_MAPPINGS")
    ]
    
    new_df = pd.concat([unmapped_lex_df, unmapped_mondo_df], axis=0)
    return new_df

def export_unmatched_exact(unmapped_df, match_type, fn):
        
    unmapped_exact = unmapped_df[(unmapped_df['comment'] == match_type) & (unmapped_df['predicate_id'] == 'skos:exactMatch')]
    unmapped_exact = replace_by_mondo_preds(unmapped_exact)
    robot_row_dict = {
        "subject_id":["ID"],
        "predicate_id": ["A oboInOwl:hasDbXref"],
        "object_id": [">A oboInOwl:source"],
        "object_label": [">A sssom:object_label"]
    }
    column_seq = unmapped_exact.columns
    unmapped_exact = pd.concat([pd.DataFrame.from_dict(robot_row_dict, orient='columns'),unmapped_exact] , axis=0)
#     unmapped_exact.index += 1
#     unmapped_exact = unmapped_exact.sort_index()
    unmapped_exact = unmapped_exact[column_seq]
    unmapped_exact.to_csv(join(dir_name, fn), sep='\t', index = False)
    return unmapped_exact.head()

def make_msdf(df, prefix_map, meta):
    combined_msdf = MappingSetDataFrame(df=df, prefix_map=prefix_map, metadata=meta)
    return combined_msdf

def mapped_curie_list(df):
    all_id_df = pd.DataFrame(pd.concat([df['subject_id'], df['object_id']]))\
                .drop_duplicates(ignore_index=True)
    all_id_df = all_id_df[~all_id_df[0].str.startswith('MONDO')]
    return all_id_df[0].to_list()

def replace_by_mondo_preds(df):
    mondo_codes = {
        "skos:exactMatch": "MONDO:equivalentTo",
        "skos:relatedMatch": "MONDO:relatedTo",
        "skos:narrowMatch": "MONDO:mondoIsBroaderThanSource",
        "skos:broadMatch": "MONDO:mondoIsNarrowerThanSource",
    }
    df['predicate_id'] = df['predicate_id'].apply(lambda x: mondo_codes[x] if x in mondo_codes else x)
    return df

# %%
# %%time
msdf_lex = parse_sssom_table(lexmatch_file)
msdf_mondo = parse_sssom_table(mondo_sssom)

# Use OAK to get 'object_label'
ontology_resource = OntologyResource(slug='../ontology/tmp/merged.db', local=True)
oi = SqlImplementation(ontology_resource)
# Out:
# CPU times: user 1min 4s, sys: 894 ms, total: 1min 5s
# Wall time: 1min 6s

# %%
# %%time
exclusion_list = []

for file_path in exclusion_files:
    with open(file_path) as f_input:
        exclusion_list.extend(f_input.read().split('\n'))
        
exclusion_list
# Out:
# CPU times: user 17.6 ms, sys: 3.65 ms, total: 21.2 ms
# Wall time: 22.5 ms
# ['DOID:0040001',
#  'DOID:0040002',
#  'DOID:0040003',
#  'DOID:0040004',
#  'DOID:0040005',
#  'DOID:0040006',
#  'DOID:0040007',
#  'DOID:0040008',
#  'DOID:0040009',
#  'DOID:0040010',
#  'DOID:0040011',
#  'DOID:0040012',
#  'DOID:0040013',
#  'DOID:0040014',
#  'DOID:0040015',
#  'DOID:0040016',
#  'DOID:0040017',
#  'DOID:0040018',
#  'DOID:0040019',
#  'DOID:0040020',
#  'DOID:0040021',
#  'DOID:0040022',
#  'DOID:0040023',
#  'DOID:0040024',
#  'DOID:0040025',
#  'DOID:0040026',
#  'DOID:0040027',
#  'DOID:0040028',
#  'DOID:0040029',
#  'DOID:0040030',
#  'DOID:0040031',
#  'DOID:0040032',
#  'DOID:0040033',
#  'DOID:0040034',
#  'DOID:0040035',
#  'DOID:0040036',
#  'DOID:0040037',
#  'DOID:0040038',
#  'DOID:0040040',
#  'DOID:0040041',
#  'DOID:0040042',
#  'DOID:0040043',
#  'DOID:0040044',
#  'DOID:0040045',
#  'DOID:0040046',
#  'DOID:0040047',
#  'DOID:0040048',
#  'DOID:0040049',
#  'DOID:0040050',
#  'DOID:0040051',
#  'DOID:0040052',
#  'DOID:0040053',
#  'DOID:0040054',
#  'DOID:0040055',
#  'DOID:0040056',
#  'DOID:0040057',
#  'DOID:0040058',
#  'DOID:0040059',
#  'DOID:0040061',
#  'DOID:0040062',
#  'DOID:0040063',
#  'DOID:0040064',
#  'DOID:0040065',
#  'DOID:0040066',
#  'DOID:0040067',
#  'DOID:0040068',
#  'DOID:0040069',
#  'DOID:0040070',
#  'DOID:0040071',
#  'DOID:0040072',
#  'DOID:0040073',
#  'DOID:0040074',
#  'DOID:0040075',
#  'DOID:0040076',
#  'DOID:0040077',
#  'DOID:0040078',
#  'DOID:0040079',
#  'DOID:0040080',
#  'DOID:0040081',
#  'DOID:0040082',
#  'DOID:0040101',
#  'DOID:0040102',
#  'DOID:0040103',
#  'DOID:0040104',
#  'DOID:0050001',
#  'DOID:0050002',
#  'DOID:0050003',
#  'DOID:0050007',
#  'DOID:0050009',
#  'DOID:0050010',
#  'DOID:0050011',
#  'DOID:0050013',
#  'DOID:0050014',
#  'DOID:0050015',
#  'DOID:0050024',
#  'DOID:0050053',
#  'DOID:0050063',
#  'DOID:0050065',
#  'DOID:0050066',
#  'DOID:0050067',
#  'DOID:0050068',
#  'DOID:0050069',
#  'DOID:0050070',
#  'DOID:0050074',
#  'DOID:0050075',
#  'DOID:0050078',
#  'DOID:0050079',
#  'DOID:0050080',
#  'DOID:0050082',
#  'DOID:0050084',
#  'DOID:0050085',
#  'DOID:0050086',
#  'DOID:0050088',
#  'DOID:0050089',
#  'DOID:0050090',
#  'DOID:0050091',
#  'DOID:0050092',
#  'DOID:0050093',
#  'DOID:0050094',
#  'DOID:0050095',
#  'DOID:0050098',
#  'DOID:0050099',
#  'DOID:0050100',
#  'DOID:0050101',
#  'DOID:0050102',
#  'DOID:0050103',
#  'DOID:0050104',
#  'DOID:0050106',
#  'DOID:0050107',
#  'DOID:0050108',
#  'DOID:0050110',
#  'DOID:0050111',
#  'DOID:0050112',
#  'DOID:0050113',
#  'DOID:0050115',
#  'DOID:0050119',
#  'DOID:0050123',
#  'DOID:0050126',
#  'DOID:0050139',
#  'DOID:0050151',
#  'DOID:0050154',
#  'DOID:0050162',
#  'DOID:0050163',
#  'DOID:0050164',
#  'DOID:0050165',
#  'DOID:0050170',
#  'DOID:0050171',
#  'DOID:0050172',
#  'DOID:0050173',
#  'DOID:0050178',
#  'DOID:0050180',
#  'DOID:0050181',
#  'DOID:0050182',
#  'DOID:0050183',
#  'DOID:0050184',
#  'DOID:0050186',
#  'DOID:0050187',
#  'DOID:0050188',
#  'DOID:0050189',
#  'DOID:0050190',
#  'DOID:0050191',
#  'DOID:0050193',
#  'DOID:0050203',
#  'DOID:0050205',
#  'DOID:0050206',
#  'DOID:0050207',
#  'DOID:0050208',
#  'DOID:0050209',
#  'DOID:0050210',
#  'DOID:0050212',
#  'DOID:0050213',
#  'DOID:0050215',
#  'DOID:0050216',
#  'DOID:0050217',
#  'DOID:0050219',
#  'DOID:0050220',
#  'DOID:0050221',
#  'DOID:0050223',
#  'DOID:0050224',
#  'DOID:0050225',
#  'DOID:0050226',
#  'DOID:0050227',
#  'DOID:0050228',
#  'DOID:0050229',
#  'DOID:0050230',
#  'DOID:0050231',
#  'DOID:0050232',
#  'DOID:0050233',
#  'DOID:0050234',
#  'DOID:0050235',
#  'DOID:0050236',
#  'DOID:0050237',
#  'DOID:0050238',
#  'DOID:0050239',
#  'DOID:0050240',
#  'DOID:0050241',
#  'DOID:0050243',
#  'DOID:0050244',
#  'DOID:0050245',
#  'DOID:0050247',
#  'DOID:0050249',
#  'DOID:0050252',
#  'DOID:0050255',
#  'DOID:0050257',
#  'DOID:0050258',
#  'DOID:0050262',
#  'DOID:0050263',
#  'DOID:0050264',
#  'DOID:0050265',
#  'DOID:0050267',
#  'DOID:0050271',
#  'DOID:0050272',
#  'DOID:0050273',
#  'DOID:0050274',
#  'DOID:0050275',
#  'DOID:0050276',
#  'DOID:0050277',
#  'DOID:0050280',
#  'DOID:0050281',
#  'DOID:0050282',
#  'DOID:0050283',
#  'DOID:0050284',
#  'DOID:0050285',
#  'DOID:0050286',
#  'DOID:0050287',
#  'DOID:0050293',
#  'DOID:0050294',
#  'DOID:0050295',
#  'DOID:0050296',
#  'DOID:0050297',
#  'DOID:0050298',
#  'DOID:0050299',
#  'DOID:0050300',
#  'DOID:0050301',
#  'DOID:0050302',
#  'DOID:0050303',
#  'DOID:0050305',
#  'DOID:0050306',
#  'DOID:0050307',
#  'DOID:0050309',
#  'DOID:0050310',
#  'DOID:0050311',
#  'DOID:0050312',
#  'DOID:0050313',
#  'DOID:0050314',
#  'DOID:0050315',
#  'DOID:0050316',
#  'DOID:0050317',
#  'DOID:0050318',
#  'DOID:0050319',
#  'DOID:0050320',
#  'DOID:0050321',
#  'DOID:0050322',
#  'DOID:0050323',
#  'DOID:0050324',
#  'DOID:0050325',
#  'DOID:0050327',
#  'DOID:0050329',
#  'DOID:0050333',
#  'DOID:0050334',
#  'DOID:0050337',
#  'DOID:0050341',
#  'DOID:0050342',
#  'DOID:0050343',
#  'DOID:0050344',
#  'DOID:0050345',
#  'DOID:0050346',
#  'DOID:0050347',
#  'DOID:0050348',
#  'DOID:0050349',
#  'DOID:0050350',
#  'DOID:0050351',
#  'DOID:0050355',
#  'DOID:0050357',
#  'DOID:0050358',
#  'DOID:0050359',
#  'DOID:0050360',
#  'DOID:0050361',
#  'DOID:0050362',
#  'DOID:0050363',
#  'DOID:0050364',
#  'DOID:0050365',
#  'DOID:0050366',
#  'DOID:0050367',
#  'DOID:0050368',
#  'DOID:0050369',
#  'DOID:0050370',
#  'DOID:0050371',
#  'DOID:0050372',
#  'DOID:0050373',
#  'DOID:0050374',
#  'DOID:0050375',
#  'DOID:0050376',
#  'DOID:0050377',
#  'DOID:0050378',
#  'DOID:0050379',
#  'DOID:0050380',
#  'DOID:0050381',
#  'DOID:0050384',
#  'DOID:0050385',
#  'DOID:0050386',
#  'DOID:0050388',
#  'DOID:0050389',
#  'DOID:0050390',
#  'DOID:0050391',
#  'DOID:0050392',
#  'DOID:0050393',
#  'DOID:0050394',
#  'DOID:0050395',
#  'DOID:0050396',
#  'DOID:0050397',
#  'DOID:0050399',
#  'DOID:0050400',
#  'DOID:0050401',
#  'DOID:0050402',
#  'DOID:0050403',
#  'DOID:0050404',
#  'DOID:0050405',
#  'DOID:0050406',
#  'DOID:0050407',
#  'DOID:0050408',
#  'DOID:0050409',
#  'DOID:0050410',
#  'DOID:0050411',
#  'DOID:0050412',
#  'DOID:0050413',
#  'DOID:0050414',
#  'DOID:0050415',
#  'DOID:0050416',
#  'DOID:0050417',
#  'DOID:0050418',
#  'DOID:0050420',
#  'DOID:0050421',
#  'DOID:0050422',
#  'DOID:0050423',
#  'DOID:0050455',
#  'DOID:0050478',
#  'DOID:0050479',
#  'DOID:0050482',
#  'DOID:0050483',
#  'DOID:0050492',
#  'DOID:0050493',
#  'DOID:0050494',
#  'DOID:0050496',
#  'DOID:0050497',
#  'DOID:0050498',
#  'DOID:0050499',
#  'DOID:0050500',
#  'DOID:0050501',
#  'DOID:0050502',
#  'DOID:0050503',
#  'DOID:0050504',
#  'DOID:0050505',
#  'DOID:0050506',
#  'DOID:0050507',
#  'DOID:0050509',
#  'DOID:0050510',
#  'DOID:0050511',
#  'DOID:0050512',
#  'DOID:0050519',
#  'DOID:0050520',
#  'DOID:0050525',
#  'DOID:0050527',
#  'DOID:0050531',
#  'DOID:0050532',
#  'DOID:0050533',
#  'DOID:0050536',
#  'DOID:0050550',
#  'DOID:0050551',
#  'DOID:0050556',
#  'DOID:0050583',
#  'DOID:0050616',
#  'DOID:0050617',
#  'DOID:0050618',
#  'DOID:0050643',
#  'DOID:0050652',
#  'DOID:0050653',
#  'DOID:0050707',
#  'DOID:0050756',
#  'DOID:0050761',
#  'DOID:0050780',
#  'DOID:0050815',
#  'DOID:0050819',
#  'DOID:0050867',
#  'DOID:0050875',
#  'DOID:0050878',
#  'DOID:0050966',
#  'DOID:0060006',
#  'DOID:0060035',
#  'DOID:0060052',
#  'DOID:0060053',
#  'DOID:0060057',
#  'DOID:0060064',
#  'DOID:0060069',
#  'DOID:0060101',
#  'DOID:0060120',
#  'DOID:0060171',
#  'DOID:0060208',
#  'DOID:0060492',
#  'DOID:0060495',
#  'DOID:0060496',
#  'DOID:0060497',
#  'DOID:0060498',
#  'DOID:0060500',
#  'DOID:0060501',
#  'DOID:0060502',
#  'DOID:0060503',
#  'DOID:0060504',
#  'DOID:0060505',
#  'DOID:0060506',
#  'DOID:0060507',
#  'DOID:0060508',
#  'DOID:0060509',
#  'DOID:0060510',
#  'DOID:0060511',
#  'DOID:0060512',
#  'DOID:0060513',
#  'DOID:0060514',
#  'DOID:0060515',
#  'DOID:0060516',
#  'DOID:0060517',
#  'DOID:0060518',
#  'DOID:0060519',
#  'DOID:0060520',
#  'DOID:0060521',
#  'DOID:0060522',
#  'DOID:0060523',
#  'DOID:0060524',
#  'DOID:0060525',
#  'DOID:0060526',
#  'DOID:0060527',
#  'DOID:0060528',
#  'DOID:0060529',
#  'DOID:0060530',
#  'DOID:0060531',
#  'DOID:0060532',
#  'DOID:0060561',
#  'DOID:0060600',
#  'DOID:0060605',
#  'DOID:0060771',
#  'DOID:0060829',
#  'DOID:0060904',
#  'DOID:0070001',
#  'DOID:0070075',
#  'DOID:0070076',
#  'DOID:0070101',
#  'DOID:0070102',
#  'DOID:0070103',
#  'DOID:0070104',
#  'DOID:0070105',
#  'DOID:0070106',
#  'DOID:0070107',
#  'DOID:0070108',
#  'DOID:0070109',
#  'DOID:0070110',
#  'DOID:0070175',
#  'DOID:0070190',
#  'DOID:0070312',
#  'DOID:0070334',
#  'DOID:0070335',
#  'DOID:0080013',
#  'DOID:0080017',
#  'DOID:0080022',
#  'DOID:0080023',
#  'DOID:0080024',
#  'DOID:0080034',
#  'DOID:0080048',
#  'DOID:0080088',
#  'DOID:0080220',
#  'DOID:0080221',
#  'DOID:0080229',
#  'DOID:0080340',
#  'DOID:0080341',
#  'DOID:0080378',
#  'DOID:0080423',
#  'DOID:0080466',
#  'DOID:0080469',
#  'DOID:0080713',
#  'DOID:0080783',
#  'DOID:0081062',
#  'DOID:0090121',
#  'DOID:0110172',
#  'DOID:0110286',
#  'DOID:0110300',
#  'DOID:0110301',
#  'DOID:0110302',
#  'DOID:0110325',
#  'DOID:0110466',
#  'DOID:0110631',
#  'DOID:0110649',
#  'DOID:0110748',
#  'DOID:0110762',
#  'DOID:0111372',
#  'DOID:0111810',
#  'DOID:10000',
#  'DOID:10007',
#  'DOID:1001',
#  'DOID:10012',
#  'DOID:10013',
#  'DOID:10015',
#  'DOID:10018',
#  'DOID:10038',
#  'DOID:10042',
#  'DOID:10045',
#  'DOID:10048',
#  'DOID:10049',
#  'DOID:10053',
#  'DOID:10059',
#  'DOID:10066',
#  'DOID:10111',
#  'DOID:10114',
#  'DOID:10116',
#  'DOID:10120',
#  'DOID:10121',
#  'DOID:10141',
#  'DOID:10142',
#  'DOID:10144',
#  'DOID:10145',
#  'DOID:10150',
#  'DOID:1016',
#  'DOID:10173',
#  'DOID:10182',
#  'DOID:10191',
#  'DOID:10202',
#  'DOID:10204',
#  'DOID:10210',
#  'DOID:10220',
#  'DOID:10222',
#  'DOID:10226',
#  'DOID:10229',
#  'DOID:10233',
#  'DOID:10237',
#  'DOID:10238',
#  'DOID:10239',
#  'DOID:10240',
#  'DOID:10245',
#  'DOID:10255',
#  'DOID:10256',
#  'DOID:10257',
#  'DOID:10263',
#  'DOID:10265',
#  'DOID:10274',
#  'DOID:10277',
#  'DOID:10278',
#  'DOID:10279',
#  'DOID:10280',
#  'DOID:10288',
#  'DOID:10294',
#  'DOID:10295',
#  'DOID:10296',
#  'DOID:10304',
#  'DOID:10305',
#  'DOID:10307',
#  'DOID:10309',
#  'DOID:10311',
#  'DOID:10312',
#  'DOID:10332',
#  'DOID:10334',
#  'DOID:10338',
#  'DOID:10339',
#  'DOID:10340',
#  'DOID:10342',
#  'DOID:10343',
#  'DOID:10351',
#  'DOID:10367',
#  'DOID:1038',
#  'DOID:10380',
#  'DOID:10381',
#  'DOID:10384',
#  'DOID:1042',
#  'DOID:10437',
#  'DOID:1044',
#  'DOID:10447',
#  'DOID:1045',
#  'DOID:10469',
#  'DOID:1047',
#  'DOID:10472',
#  'DOID:10473',
#  'DOID:10483',
#  'DOID:10489',
#  'DOID:10494',
#  'DOID:10501',
#  'DOID:10505',
#  'DOID:10508',
#  'DOID:10510',
#  'DOID:10521',
#  'DOID:10527',
#  'DOID:10528',
#  'DOID:10529',
#  'DOID:1053',
#  'DOID:10531',
#  'DOID:10532',
#  'DOID:10535',
#  'DOID:10537',
#  'DOID:1054',
#  'DOID:10545',
#  'DOID:10549',
#  'DOID:1055',
#  'DOID:10551',
#  'DOID:10557',
#  'DOID:10561',
#  'DOID:10564',
#  'DOID:10569',
#  'DOID:1057',
#  'DOID:10574',
#  'DOID:1058',
#  'DOID:10585',
#  'DOID:10594',
#  'DOID:10597',
#  'DOID:10602',
#  'DOID:1061',
#  'DOID:10621',
#  'DOID:10626',
#  'DOID:10630',
#  'DOID:10645',
#  'DOID:10659',
#  'DOID:10689',
#  'DOID:10708',
#  'DOID:10717',
#  'DOID:10731',
#  'DOID:10747',
#  'DOID:1075',
#  'DOID:10760',
#  'DOID:10764',
#  'DOID:1077',
#  'DOID:10774',
#  'DOID:1078',
#  'DOID:10788',
#  'DOID:10795',
#  'DOID:10803',
#  'DOID:10815',
#  'DOID:10818',
#  'DOID:10827',
#  'DOID:10836',
#  'DOID:10837',
#  'DOID:10838',
#  'DOID:10848',
#  'DOID:1086',
#  'DOID:10875',
#  'DOID:10877',
#  'DOID:10901',
#  'DOID:10902',
#  'DOID:10910',
#  'DOID:10911',
#  'DOID:10918',
#  'DOID:10919',
#  'DOID:10922',
#  'DOID:10924',
#  'DOID:10925',
#  'DOID:10957',
#  'DOID:10958',
#  'DOID:10959',
#  'DOID:1097',
#  'DOID:10978',
#  'DOID:10979',
#  'DOID:10980',
#  'DOID:10998',
#  'DOID:11000',
#  'DOID:11001',
#  'DOID:11002',
#  'DOID:11003',
#  'DOID:11005',
#  'DOID:11018',
#  'DOID:11019',
#  'DOID:11020',
#  'DOID:11027',
#  'DOID:1103',
#  'DOID:1105',
#  'DOID:11056',
#  'DOID:11074',
#  'DOID:1109',
#  'DOID:11091',
#  'DOID:11092',
#  'DOID:11093',
#  'DOID:11096',
#  'DOID:11097',
#  'DOID:11099',
#  'DOID:1110',
#  'DOID:11106',
#  'DOID:11107',
#  'DOID:1111',
#  'DOID:11110',
#  'DOID:11118',
#  'DOID:1112',
#  'DOID:1113',
#  'DOID:11144',
#  'DOID:11145',
#  'DOID:11147',
#  'DOID:11150',
#  'DOID:11158',
#  'DOID:11163',
#  'DOID:11167',
#  'DOID:11169',
#  'DOID:11170',
#  'DOID:11171',
#  'DOID:11172',
#  'DOID:11179',
#  'DOID:11182',
#  'DOID:11183',
#  'DOID:1119',
#  'DOID:11215',
#  'DOID:1122',
#  'DOID:11248',
#  'DOID:11259',
#  'DOID:11261',
#  'DOID:11264',
#  'DOID:11268',
#  'DOID:11271',
#  'DOID:11275',
#  'DOID:11284',
#  'DOID:11286',
#  'DOID:11287',
#  'DOID:113',
#  'DOID:11307',
#  'DOID:11308',
#  'DOID:11309',
#  'DOID:11314',
#  'DOID:11327',
#  'DOID:11340',
#  'DOID:11341',
#  'DOID:11346',
#  'DOID:11347',
#  'DOID:11349',
#  'DOID:11350',
#  'DOID:11352',
#  'DOID:11361',
#  'DOID:11377',
#  'DOID:11403',
#  'DOID:11404',
#  'DOID:11409',
#  'DOID:1141',
#  'DOID:11418',
#  'DOID:11421',
#  'DOID:11436',
#  'DOID:11441',
#  'DOID:11442',
#  'DOID:11451',
#  'DOID:11489',
#  'DOID:11490',
#  'DOID:1150',
#  'DOID:11523',
#  'DOID:11524',
#  'DOID:11525',
#  'DOID:11535',
#  'DOID:11575',
#  'DOID:11578',
#  'DOID:11582',
#  'DOID:11584',
#  'DOID:11597',
#  'DOID:11600',
#  'DOID:11604',
#  'DOID:11606',
#  'DOID:11607',
#  'DOID:11649',
#  'DOID:11650',
#  'DOID:11654',
#  'DOID:11662',
#  'DOID:11680',
#  'DOID:11683',
#  'DOID:11696',
#  'DOID:11699',
#  'DOID:11705',
#  'DOID:11711',
#  'DOID:11730',
#  'DOID:11732',
#  'DOID:11733',
#  'DOID:11734',
#  'DOID:11735',
#  'DOID:11741',
#  'DOID:11753',
#  'DOID:11756',
#  'DOID:11770',
#  'DOID:11775',
#  'DOID:11802',
#  'DOID:11806',
#  'DOID:11810',
#  'DOID:11815',
#  'DOID:11828',
#  'DOID:1183',
#  'DOID:11837',
#  'DOID:11849',
#  'DOID:11852',
#  'DOID:11854',
#  'DOID:11855',
#  'DOID:11856',
#  'DOID:11861',
#  'DOID:11862',
#  'DOID:11868',
#  'DOID:11872',
#  'DOID:11873',
#  'DOID:11892',
#  'DOID:11893',
#  'DOID:11896',
#  'DOID:11897',
#  'DOID:11902',
#  'DOID:11939',
#  'DOID:11943',
#  'DOID:11944',
#  'DOID:11945',
#  'DOID:11946',
#  'DOID:11947',
#  'DOID:11950',
#  'DOID:11952',
#  'DOID:11954',
#  'DOID:11955',
#  'DOID:11964',
#  'DOID:11970',
#  'DOID:11977',
#  'DOID:11978',
#  'DOID:11987',
#  'DOID:12000',
#  'DOID:12017',
#  'DOID:12019',
#  'DOID:12020',
#  'DOID:12021',
#  'DOID:12022',
#  'DOID:1204',
#  'DOID:12040',
#  'DOID:12052',
#  'DOID:12054',
#  'DOID:12056',
#  'DOID:12058',
#  'DOID:12061',
#  'DOID:12065',
#  'DOID:12076',
#  'DOID:12091',
#  'DOID:12092',
#  'DOID:12097',
#  'DOID:12104',
#  'DOID:12106',
#  'DOID:12107',
#  'DOID:12111',
#  'DOID:12113',
#  'DOID:12115',
#  'DOID:12121',
#  'DOID:1213',
#  'DOID:12133',
#  'DOID:12135',
#  'DOID:12136',
#  'DOID:12141',
#  'DOID:1215',
#  'DOID:12150',
#  'DOID:12151',
#  'DOID:12180',
#  'DOID:12189',
#  'DOID:122',
#  'DOID:12204',
#  'DOID:1221',
#  'DOID:12210',
#  'DOID:12221',
#  'DOID:12224',
#  'DOID:12226',
#  'DOID:12228',
#  'DOID:12245',
#  'DOID:12251',
#  'DOID:12252',
#  'DOID:12254',
#  'DOID:12255',
#  'DOID:12256',
#  'DOID:12258',
#  'DOID:12268',
#  'DOID:12269',
#  'DOID:12274',
#  'DOID:1228',
#  'DOID:12284',
#  'DOID:12292',
#  'DOID:12301',
#  'DOID:12302',
#  'DOID:1231',
#  'DOID:1232',
#  'DOID:12324',
#  'DOID:12338',
#  'DOID:12346',
#  'DOID:12356',
#  'DOID:12378',
#  'DOID:12379',
#  'DOID:1238',
#  'DOID:12380',
#  'DOID:1239',
#  'DOID:12392',
#  'DOID:12396',
#  'DOID:12404',
#  'DOID:12417',
#  'DOID:12448',
#  'DOID:1249',
#  'DOID:12508',
#  'DOID:12525',
#  'DOID:1253',
#  'DOID:12538',
#  'DOID:12539',
#  'DOID:12541',
#  'DOID:12542',
#  'DOID:12543',
#  'DOID:12551',
#  'DOID:12555',
#  'DOID:12569',
#  'DOID:1257',
#  'DOID:12582',
#  'DOID:12584',
#  'DOID:12604',
#  'DOID:12605',
#  'DOID:12608',
#  'DOID:1261',
#  'DOID:12610',
#  'DOID:12612',
#  'DOID:12633',
#  'DOID:12634',
#  'DOID:12647',
#  'DOID:1265',
#  'DOID:12651',
#  'DOID:12670',
#  'DOID:1269',
#  'DOID:12694',
#  'DOID:12702',
#  'DOID:12710',
#  'DOID:12713',
#  'DOID:12715',
#  'DOID:12722',
#  'DOID:12723',
#  'DOID:12724',
#  'DOID:12727',
#  'DOID:12739',
#  'DOID:1275',
#  'DOID:12758',
#  'DOID:12763',
#  'DOID:12765',
#  'DOID:12773',
#  'DOID:12779',
#  'DOID:12784',
#  'DOID:12796',
#  'DOID:128',
#  'DOID:12819',
#  'DOID:12838',
#  'DOID:12839',
#  'DOID:12840',
#  'DOID:12843',
#  'DOID:12852',
#  'DOID:12853',
#  'DOID:12854',
#  'DOID:12860',
#  'DOID:12863',
#  'DOID:12864',
#  'DOID:12879',
#  'DOID:12881',
#  'DOID:12888',
#  'DOID:12910',
#  'DOID:12921',
#  'DOID:12922',
#  'DOID:12923',
#  'DOID:12928',
#  'DOID:12936',
#  'DOID:12973',
#  'DOID:12983',
#  'DOID:12985',
#  'DOID:130',
#  'DOID:1301',
#  'DOID:13019',
#  'DOID:13020',
#  'DOID:13021',
#  'DOID:13023',
#  'DOID:13032',
#  'DOID:13040',
#  'DOID:13047',
#  'DOID:13049',
#  'DOID:1305',
#  'DOID:1306',
#  'DOID:13063',
#  'DOID:13076',
#  'DOID:13077',
#  'DOID:1308',
#  'DOID:1311',
#  'DOID:1313',
#  'DOID:1314',
#  'DOID:13149',
#  'DOID:13157',
#  'DOID:13164',
#  'DOID:13165',
#  'DOID:13175',
#  'DOID:13177',
#  'DOID:13192',
#  'DOID:13194',
#  'DOID:13202',
#  'DOID:13211',
#  'DOID:13212',
#  'DOID:13213',
#  'DOID:13219',
#  'DOID:13224',
#  'DOID:1323',
#  'DOID:13232',
#  'DOID:13251',
#  'DOID:13253',
#  'DOID:13257',
#  'DOID:13262',
#  'DOID:13273',
#  'DOID:13274',
#  'DOID:13275',
#  'DOID:13277',
#  'DOID:13278',
#  'DOID:13285',
#  'DOID:13305',
#  ...]

# %%
# %%time
all_lex_ids = mapped_curie_list(msdf_lex.df)
all_mondo_ids = mapped_curie_list(msdf_mondo.df)

in_lex_but_not_mondo_list = [x for x in all_lex_ids if x not in all_mondo_ids and x not in exclusion_list]
in_mondo_but_not_lex_list = [x for x in all_mondo_ids if x not in all_lex_ids and x not in exclusion_list]
# Out:
# CPU times: user 8min 10s, sys: 607 ms, total: 8min 11s
# Wall time: 8min 12s

# %%
in_lex_but_not_mondo_list
# Out:
# ['DOID:0060042',
#  'DOID:0060204',
#  'DOID:0070020',
#  'DOID:0070141',
#  'DOID:0070212',
#  'DOID:0070309',
#  'DOID:0070311',
#  'DOID:0070326',
#  'DOID:0070327',
#  'DOID:0070331',
#  'DOID:0070333',
#  'DOID:0070336',
#  'DOID:0070341',
#  'DOID:0070343',
#  'DOID:0070348',
#  'DOID:0070349',
#  'DOID:0070351',
#  'DOID:0070358',
#  'DOID:0070359',
#  'DOID:0070360',
#  'DOID:0070361',
#  'DOID:0070362',
#  'DOID:0080380',
#  'DOID:0080390',
#  'DOID:0080407',
#  'DOID:0080410',
#  'DOID:0080411',
#  'DOID:0080503',
#  'DOID:0080511',
#  'DOID:0080546',
#  'DOID:0080574',
#  'DOID:0080594',
#  'DOID:0080597',
#  'DOID:0080602',
#  'DOID:0080606',
#  'DOID:0080607',
#  'DOID:0080610',
#  'DOID:0080612',
#  'DOID:0080638',
#  'DOID:0080641',
#  'DOID:0080644',
#  'DOID:0080645',
#  'DOID:0080646',
#  'DOID:0080647',
#  'DOID:0080650',
#  'DOID:0080651',
#  'DOID:0080652',
#  'DOID:0080661',
#  'DOID:0080662',
#  'DOID:0080663',
#  'DOID:0080664',
#  'DOID:0080665',
#  'DOID:0080666',
#  'DOID:0080669',
#  'DOID:0080670',
#  'DOID:0080671',
#  'DOID:0080672',
#  'DOID:0080673',
#  'DOID:0080674',
#  'DOID:0080675',
#  'DOID:0080676',
#  'DOID:0080677',
#  'DOID:0080678',
#  'DOID:0080679',
#  'DOID:0080680',
#  'DOID:0080681',
#  'DOID:0080682',
#  'DOID:0080683',
#  'DOID:0080684',
#  'DOID:0080685',
#  'DOID:0080686',
#  'DOID:0080687',
#  'DOID:0080688',
#  'DOID:0080689',
#  'DOID:0080690',
#  'DOID:0080691',
#  'DOID:0080692',
#  'DOID:0080693',
#  'DOID:0080695',
#  'DOID:0080696',
#  'DOID:0080697',
#  'DOID:0080698',
#  'DOID:0080699',
#  'DOID:0080700',
#  'DOID:0080701',
#  'DOID:0080705',
#  'DOID:0080715',
#  'DOID:0080716',
#  'DOID:0080717',
#  'DOID:0080718',
#  'DOID:0080719',
#  'DOID:0080720',
#  'DOID:0080721',
#  'DOID:0080722',
#  'DOID:0080723',
#  'DOID:0080724',
#  'DOID:0080725',
#  'DOID:0080726',
#  'DOID:0080727',
#  'DOID:0080728',
#  'DOID:0080729',
#  'DOID:0080730',
#  'DOID:0080731',
#  'DOID:0080732',
#  'DOID:0080733',
#  'DOID:0080734',
#  'DOID:0080735',
#  'DOID:0080736',
#  'DOID:0080737',
#  'DOID:0080738',
#  'DOID:0080739',
#  'DOID:0080741',
#  'DOID:0080743',
#  'DOID:0080744',
#  'DOID:0080745',
#  'DOID:0080746',
#  'DOID:0080747',
#  'DOID:0080749',
#  'DOID:0080750',
#  'DOID:0080751',
#  'DOID:0080753',
#  'DOID:0080754',
#  'DOID:0080755',
#  'DOID:0080756',
#  'DOID:0080757',
#  'DOID:0080758',
#  'DOID:0080759',
#  'DOID:0080760',
#  'DOID:0080761',
#  'DOID:0080762',
#  'DOID:0080764',
#  'DOID:0080765',
#  'DOID:0080766',
#  'DOID:0080767',
#  'DOID:0080768',
#  'DOID:0080769',
#  'DOID:0080770',
#  'DOID:0080771',
#  'DOID:0080772',
#  'DOID:0080774',
#  'DOID:0080775',
#  'DOID:0080776',
#  'DOID:0080777',
#  'DOID:0080778',
#  'DOID:0080779',
#  'DOID:0080780',
#  'DOID:0080781',
#  'DOID:0080784',
#  'DOID:0080785',
#  'DOID:0080786',
#  'DOID:0080787',
#  'DOID:0080788',
#  'DOID:0080789',
#  'DOID:0080790',
#  'DOID:0080791',
#  'DOID:0080792',
#  'DOID:0080794',
#  'DOID:0080795',
#  'DOID:0080796',
#  'DOID:0080797',
#  'DOID:0080798',
#  'DOID:0080799',
#  'DOID:0080800',
#  'DOID:0080801',
#  'DOID:0080802',
#  'DOID:0080803',
#  'DOID:0080804',
#  'DOID:0080805',
#  'DOID:0080806',
#  'DOID:0080807',
#  'DOID:0080811',
#  'DOID:0080815',
#  'DOID:0080820',
#  'DOID:0080821',
#  'DOID:0080828',
#  'DOID:0080829',
#  'DOID:0080833',
#  'DOID:0080835',
#  'DOID:0080836',
#  'DOID:0080837',
#  'DOID:0080840',
#  'DOID:0080841',
#  'DOID:0080842',
#  'DOID:0080843',
#  'DOID:0080844',
#  'DOID:0080845',
#  'DOID:0080848',
#  'DOID:0080849',
#  'DOID:0080850',
#  'DOID:0080851',
#  'DOID:0080852',
#  'DOID:0080854',
#  'DOID:0080855',
#  'DOID:0080856',
#  'DOID:0080857',
#  'DOID:0080858',
#  'DOID:0080859',
#  'DOID:0080860',
#  'DOID:0080861',
#  'DOID:0080862',
#  'DOID:0080863',
#  'DOID:0080864',
#  'DOID:0080865',
#  'DOID:0080866',
#  'DOID:0080867',
#  'DOID:0080868',
#  'DOID:0080869',
#  'DOID:0080870',
#  'DOID:0080871',
#  'DOID:0080872',
#  'DOID:0080873',
#  'DOID:0080874',
#  'DOID:0080876',
#  'DOID:0080877',
#  'DOID:0080878',
#  'DOID:0080882',
#  'DOID:0080883',
#  'DOID:0080884',
#  'DOID:0080885',
#  'DOID:0080886',
#  'DOID:0080887',
#  'DOID:0080888',
#  'DOID:0080889',
#  'DOID:0080890',
#  'DOID:0080892',
#  'DOID:0080893',
#  'DOID:0080895',
#  'DOID:0080896',
#  'DOID:0080897',
#  'DOID:0080898',
#  'DOID:0080899',
#  'DOID:0080904',
#  'DOID:0080905',
#  'DOID:0080906',
#  'DOID:0080907',
#  'DOID:0080908',
#  'DOID:0080909',
#  'DOID:0080910',
#  'DOID:0080911',
#  'DOID:0080912',
#  'DOID:0080913',
#  'DOID:0080914',
#  'DOID:0080915',
#  'DOID:0080916',
#  'DOID:0080917',
#  'DOID:0080918',
#  'DOID:0080919',
#  'DOID:0080920',
#  'DOID:0080921',
#  'DOID:0080922',
#  'DOID:0080923',
#  'DOID:0080924',
#  'DOID:0080925',
#  'DOID:0080926',
#  'DOID:0080927',
#  'DOID:0080928',
#  'DOID:0080929',
#  'DOID:0080930',
#  'DOID:0080931',
#  'DOID:0080932',
#  'DOID:0080933',
#  'DOID:0080934',
#  'DOID:0080936',
#  'DOID:0080937',
#  'DOID:0080939',
#  'DOID:0080940',
#  'DOID:0080941',
#  'DOID:0080942',
#  'DOID:0080943',
#  'DOID:0080944',
#  'DOID:0080945',
#  'DOID:0080946',
#  'DOID:0080947',
#  'DOID:0080948',
#  'DOID:0080949',
#  'DOID:0080950',
#  'DOID:0080951',
#  'DOID:0080952',
#  'DOID:0080953',
#  'DOID:0080954',
#  'DOID:0080956',
#  'DOID:0080957',
#  'DOID:0080958',
#  'DOID:0080959',
#  'DOID:0080960',
#  'DOID:0080962',
#  'DOID:0080963',
#  'DOID:0080964',
#  'DOID:0080965',
#  'DOID:0080966',
#  'DOID:0080967',
#  'DOID:0080968',
#  'DOID:0080969',
#  'DOID:0080970',
#  'DOID:0080971',
#  'DOID:0080972',
#  'DOID:0080973',
#  'DOID:0080974',
#  'DOID:0080975',
#  'DOID:0080976',
#  'DOID:0080977',
#  'DOID:0080978',
#  'DOID:0080979',
#  'DOID:0080980',
#  'DOID:0080981',
#  'DOID:0080984',
#  'DOID:0080985',
#  'DOID:0080986',
#  'DOID:0080987',
#  'DOID:0080988',
#  'DOID:0080990',
#  'DOID:0080991',
#  'DOID:0080996',
#  'DOID:0080997',
#  'DOID:0080998',
#  'DOID:0081000',
#  'DOID:0081001',
#  'DOID:0081002',
#  'DOID:0081003',
#  'DOID:0081004',
#  'DOID:0081007',
#  'DOID:0081008',
#  'DOID:0081009',
#  'DOID:0081010',
#  'DOID:0081011',
#  'DOID:0081015',
#  'DOID:0081016',
#  'DOID:0081017',
#  'DOID:0081019',
#  'DOID:0081020',
#  'DOID:0081021',
#  'DOID:0081022',
#  'DOID:0081023',
#  'DOID:0081024',
#  'DOID:0081025',
#  'DOID:0081028',
#  'DOID:0081030',
#  'DOID:0081031',
#  'DOID:0081034',
#  'DOID:0081036',
#  'DOID:0081037',
#  'DOID:0081041',
#  'DOID:0081042',
#  'DOID:0081043',
#  'DOID:0081044',
#  'DOID:0081045',
#  'DOID:0081046',
#  'DOID:0081047',
#  'DOID:0081048',
#  'DOID:0081049',
#  'DOID:0081050',
#  'DOID:0081051',
#  'DOID:0081055',
#  'DOID:0081057',
#  'DOID:0081058',
#  'DOID:0081059',
#  'DOID:0081060',
#  'DOID:0081061',
#  'DOID:0081063',
#  'DOID:0081064',
#  'DOID:0081065',
#  'DOID:0081066',
#  'DOID:0081067',
#  'DOID:0081068',
#  'DOID:0081069',
#  'DOID:0081072',
#  'DOID:0081073',
#  'DOID:0081074',
#  'DOID:0081075',
#  'DOID:0081076',
#  'DOID:0081077',
#  'DOID:0081078',
#  'DOID:0081079',
#  'DOID:0081080',
#  'DOID:0081081',
#  'DOID:0081082',
#  'DOID:0081083',
#  'DOID:0081084',
#  'DOID:0081085',
#  'DOID:0081086',
#  'DOID:0081087',
#  'DOID:0081088',
#  'DOID:0081089',
#  'DOID:0081091',
#  'DOID:0081092',
#  'DOID:0081093',
#  'DOID:0081094',
#  'DOID:0081095',
#  'DOID:0081096',
#  'DOID:0081097',
#  'DOID:0081098',
#  'DOID:0081099',
#  'DOID:0081100',
#  'DOID:0081101',
#  'DOID:0081102',
#  'DOID:0081104',
#  'DOID:0081105',
#  'DOID:0081106',
#  'DOID:0081107',
#  'DOID:0081108',
#  'DOID:0081109',
#  'DOID:0081110',
#  'DOID:0081111',
#  'DOID:0081112',
#  'DOID:0081113',
#  'DOID:0081114',
#  'DOID:0081115',
#  'DOID:0081116',
#  'DOID:0081117',
#  'DOID:0081118',
#  'DOID:0081119',
#  'DOID:0081120',
#  'DOID:0081122',
#  'DOID:0081123',
#  'DOID:0081124',
#  'DOID:0081126',
#  'DOID:0081127',
#  'DOID:0081128',
#  'DOID:0081129',
#  'DOID:0081130',
#  'DOID:0081131',
#  'DOID:0081134',
#  'DOID:0081135',
#  'DOID:0081136',
#  'DOID:0081137',
#  'DOID:0081138',
#  'DOID:0081139',
#  'DOID:0081140',
#  'DOID:0081141',
#  'DOID:0081142',
#  'DOID:0081144',
#  'DOID:0081145',
#  'DOID:0081146',
#  'DOID:0081147',
#  'DOID:0081148',
#  'DOID:0081149',
#  'DOID:0081150',
#  'DOID:0081151',
#  'DOID:0081152',
#  'DOID:0081153',
#  'DOID:0081154',
#  'DOID:0081155',
#  'DOID:0081156',
#  'DOID:0081157',
#  'DOID:0081158',
#  'DOID:0081159',
#  'DOID:0081160',
#  'DOID:0081161',
#  'DOID:0081162',
#  'DOID:0081163',
#  'DOID:0081164',
#  'DOID:0081168',
#  'DOID:0081169',
#  'DOID:0081175',
#  'DOID:0081176',
#  'DOID:0081177',
#  'DOID:0081178',
#  'DOID:0081179',
#  'DOID:0081180',
#  'DOID:0081181',
#  'DOID:0081182',
#  'DOID:0081183',
#  'DOID:0081184',
#  'DOID:0081185',
#  'DOID:0081186',
#  'DOID:0081187',
#  'DOID:0081188',
#  'DOID:0081189',
#  'DOID:0081190',
#  'DOID:0081191',
#  'DOID:0081192',
#  'DOID:0081193',
#  'DOID:0081194',
#  'DOID:0081195',
#  'DOID:0081196',
#  'DOID:0081197',
#  'DOID:0081198',
#  'DOID:0081199',
#  'DOID:0081200',
#  'DOID:0081201',
#  'DOID:0081202',
#  'DOID:0081203',
#  'DOID:0081204',
#  'DOID:0081205',
#  'DOID:0081206',
#  'DOID:0081207',
#  'DOID:0081208',
#  'DOID:0081209',
#  'DOID:0081210',
#  'DOID:0081211',
#  'DOID:0081212',
#  'DOID:0081213',
#  'DOID:0081214',
#  'DOID:0081215',
#  'DOID:0081216',
#  'DOID:0081217',
#  'DOID:0081218',
#  'DOID:0081219',
#  'DOID:0081220',
#  'DOID:0081221',
#  'DOID:0081222',
#  'DOID:0081223',
#  'DOID:0081224',
#  'DOID:0081225',
#  'DOID:0081226',
#  'DOID:0081227',
#  'DOID:0081228',
#  'DOID:0081229',
#  'DOID:0081230',
#  'DOID:0081231',
#  'DOID:0081232',
#  'DOID:0081233',
#  'DOID:0081234',
#  'DOID:0081237',
#  'DOID:0081238',
#  'DOID:0081240',
#  'DOID:0081241',
#  'DOID:0081242',
#  'DOID:0081243',
#  'DOID:0081244',
#  'DOID:0081245',
#  'DOID:0081246',
#  'DOID:0081247',
#  'DOID:0081248',
#  'DOID:0081249',
#  'DOID:0081250',
#  'DOID:0081251',
#  'DOID:0081252',
#  'DOID:0081253',
#  'DOID:0081254',
#  'DOID:0081255',
#  'DOID:0081256',
#  'DOID:0081257',
#  'DOID:0081259',
#  'DOID:0081260',
#  'DOID:0081261',
#  'DOID:0111180',
#  'DOID:0111189',
#  'DOID:0111190',
#  'DOID:0111203',
#  'DOID:0111214',
#  'DOID:0111218',
#  'DOID:0111223',
#  'DOID:0111224',
#  'DOID:0111244',
#  'DOID:0111246',
#  'DOID:0111269',
#  'DOID:0111275',
#  'DOID:0111278',
#  'DOID:0111349',
#  'DOID:0111369',
#  'DOID:0111388',
#  'DOID:0111421',
#  'DOID:0111444',
#  'DOID:0111452',
#  'DOID:0111576',
#  'DOID:0111592',
#  'DOID:0111596',
#  'DOID:0111603',
#  'DOID:0111605',
#  'DOID:0111607',
#  'DOID:0111608',
#  'DOID:0111609',
#  'DOID:0111610',
#  'DOID:0111622',
#  'DOID:0111664',
#  'DOID:0111706',
#  'DOID:0111708',
#  'DOID:0111710',
#  'DOID:0111711',
#  'DOID:0111715',
#  'DOID:0111721',
#  'DOID:0111729',
#  'DOID:0111731',
#  'DOID:0111737',
#  'DOID:0111741',
#  'DOID:0111757',
#  'DOID:0111761',
#  'DOID:0111790',
#  'DOID:0111791',
#  'DOID:0111792',
#  'DOID:0111793',
#  'DOID:0111794',
#  'DOID:0111795',
#  'DOID:0111796',
#  'DOID:0111797',
#  'DOID:0111798',
#  'DOID:0111799',
#  'DOID:0111800',
#  'DOID:0111801',
#  'DOID:0111802',
#  'DOID:0111803',
#  'DOID:0111804',
#  'DOID:0111805',
#  'DOID:0111806',
#  'DOID:0111808',
#  'DOID:0111809',
#  'DOID:0111811',
#  'DOID:0111812',
#  'DOID:0111813',
#  'DOID:0111814',
#  'DOID:0111815',
#  'DOID:0111816',
#  'DOID:0111817',
#  'DOID:0111818',
#  'DOID:0111819',
#  'DOID:0111820',
#  'DOID:0111821',
#  'DOID:0111822',
#  'DOID:0111823',
#  'DOID:0111824',
#  'DOID:0111825',
#  'DOID:0111826',
#  'DOID:0111827',
#  'DOID:0111828',
#  'DOID:0111829',
#  'DOID:0111830',
#  'DOID:0111831',
#  'DOID:0111832',
#  'DOID:0111833',
#  'DOID:0111834',
#  'DOID:0111835',
#  'DOID:0111836',
#  'DOID:0111837',
#  'DOID:0111838',
#  'DOID:0111839',
#  'DOID:0111840',
#  'DOID:0111841',
#  'DOID:0111842',
#  'DOID:0111843',
#  'DOID:0111844',
#  'DOID:0111845',
#  'DOID:0111846',
#  'DOID:0111847',
#  'DOID:0111848',
#  'DOID:0111849',
#  'DOID:0111850',
#  'DOID:0111851',
#  'DOID:0111852',
#  'DOID:0111853',
#  'DOID:0111854',
#  'DOID:0111855',
#  'DOID:0111856',
#  'DOID:0111857',
#  'DOID:0111858',
#  'DOID:0111859',
#  'DOID:0111860',
#  'DOID:0111861',
#  'DOID:0111862',
#  'DOID:0111863',
#  'DOID:0111864',
#  'DOID:0111865',
#  'DOID:0111866',
#  'DOID:0111867',
#  'DOID:0111868',
#  'DOID:0111869',
#  'DOID:0111870',
#  'DOID:0111871',
#  'DOID:0111872',
#  'DOID:0111873',
#  'DOID:0111874',
#  'DOID:0111875',
#  'DOID:0111876',
#  'DOID:0111877',
#  'DOID:0111878',
#  'DOID:0111879',
#  'DOID:0111880',
#  'DOID:0111881',
#  'DOID:0111882',
#  'DOID:0111883',
#  'DOID:0111884',
#  'DOID:0111885',
#  'DOID:0111886',
#  'DOID:0111887',
#  'DOID:0111888',
#  'DOID:0111889',
#  'DOID:0111890',
#  'DOID:0111891',
#  'DOID:0111892',
#  'DOID:0111893',
#  'DOID:0111894',
#  'DOID:0111895',
#  'DOID:0111896',
#  'DOID:0111897',
#  'DOID:0111898',
#  'DOID:0111899',
#  'DOID:0111900',
#  'DOID:0111901',
#  'DOID:0111902',
#  'DOID:0111903',
#  'DOID:0111904',
#  'DOID:0111905',
#  'DOID:0111906',
#  'DOID:0111907',
#  'DOID:0111908',
#  'DOID:0111909',
#  'DOID:0111911',
#  'DOID:0111912',
#  'DOID:0111913',
#  'DOID:0111914',
#  'DOID:0111915',
#  'DOID:0111916',
#  'DOID:0111917',
#  'DOID:0111918',
#  'DOID:0111919',
#  'DOID:0111920',
#  'DOID:0111921',
#  'DOID:0111922',
#  'DOID:0111923',
#  'DOID:0111924',
#  'DOID:0111925',
#  'DOID:0111926',
#  'DOID:0111927',
#  'DOID:0111928',
#  'DOID:0111929',
#  'DOID:0111930',
#  'DOID:0111931',
#  'DOID:0111932',
#  'DOID:0111933',
#  'DOID:0111934',
#  'DOID:0111935',
#  'DOID:0111936',
#  'DOID:0111937',
#  'DOID:0111938',
#  'DOID:0111939',
#  'DOID:0111940',
#  'DOID:0111941',
#  'DOID:0111942',
#  'DOID:0111943',
#  'DOID:0111944',
#  'DOID:0111945',
#  'DOID:0111946',
#  'DOID:0111947',
#  'DOID:0111948',
#  'DOID:0111949',
#  'DOID:0111950',
#  'DOID:0111951',
#  'DOID:0111952',
#  'DOID:0111953',
#  'DOID:0111954',
#  'DOID:0111955',
#  'DOID:0111956',
#  'DOID:0111957',
#  'DOID:0111958',
#  'DOID:0111959',
#  'DOID:0111960',
#  'DOID:0111961',
#  'DOID:0111962',
#  'DOID:0111967',
#  'DOID:0111968',
#  'DOID:0111969',
#  'DOID:0111970',
#  'DOID:0111971',
#  'DOID:0111972',
#  'DOID:0111973',
#  'DOID:0111974',
#  'DOID:0111975',
#  'DOID:0111976',
#  'DOID:0111978',
#  'DOID:0111979',
#  'DOID:0111980',
#  'DOID:0111981',
#  'DOID:0111982',
#  'DOID:0111983',
#  'DOID:0111984',
#  'DOID:0111985',
#  'DOID:0111986',
#  'DOID:0111987',
#  'DOID:0111988',
#  'DOID:0111989',
#  'DOID:0111990',
#  'DOID:0111991',
#  'DOID:0111992',
#  'DOID:0111993',
#  'DOID:0111994',
#  'DOID:0111995',
#  'DOID:0111996',
#  'DOID:0111997',
#  'DOID:0111998',
#  'DOID:0111999',
#  'DOID:0112000',
#  'DOID:0112001',
#  'DOID:0112002',
#  'DOID:0112003',
#  'DOID:0112004',
#  'DOID:0112005',
#  'DOID:0112006',
#  'DOID:0112007',
#  'DOID:0112008',
#  'DOID:0112009',
#  'DOID:0112010',
#  'DOID:0112011',
#  'DOID:0112012',
#  'DOID:0112013',
#  'DOID:0112014',
#  'DOID:0112015',
#  'DOID:0112016',
#  'DOID:0112017',
#  'DOID:0112018',
#  'DOID:0112019',
#  'DOID:0112020',
#  'DOID:0112021',
#  'DOID:0112022',
#  'DOID:0112023',
#  'DOID:0112024',
#  'DOID:0112025',
#  'DOID:0112026',
#  'DOID:0112027',
#  'DOID:0112028',
#  'DOID:0112029',
#  'DOID:0112030',
#  'DOID:0112031',
#  'DOID:0112032',
#  'DOID:0112033',
#  'DOID:0112034',
#  'DOID:0112035',
#  'DOID:0112036',
#  'DOID:0112037',
#  'DOID:0112038',
#  'DOID:0112039',
#  'DOID:0112040',
#  'DOID:0112041',
#  'DOID:0112042',
#  'DOID:0112043',
#  'DOID:0112044',
#  'DOID:0112045',
#  'DOID:0112046',
#  'DOID:0112047',
#  'DOID:0112048',
#  'DOID:0112049',
#  'DOID:0112050',
#  'DOID:0112051',
#  'DOID:0112052',
#  'DOID:0112053',
#  'DOID:0112054',
#  'DOID:0112055',
#  'DOID:0112056',
#  'DOID:0112057',
#  'DOID:0112058',
#  'DOID:0112059',
#  'DOID:0112060',
#  'DOID:0112061',
#  'DOID:0112062',
#  'DOID:0112063',
#  'DOID:0112064',
#  'DOID:0112065',
#  'DOID:0112066',
#  'DOID:0112067',
#  'DOID:0112068',
#  'DOID:0112069',
#  'DOID:0112070',
#  'DOID:0112071',
#  'DOID:0112072',
#  'DOID:0112073',
#  'DOID:0112074',
#  'DOID:0112075',
#  'DOID:0112076',
#  'DOID:0112077',
#  'DOID:0112078',
#  'DOID:0112079',
#  'DOID:0112080',
#  'DOID:0112081',
#  'DOID:0112082',
#  'DOID:0112083',
#  'DOID:0112084',
#  'DOID:0112085',
#  'DOID:0112086',
#  'DOID:0112087',
#  'DOID:0112088',
#  'DOID:0112089',
#  'DOID:0112090',
#  'DOID:0112091',
#  'DOID:0112092',
#  'DOID:0112093',
#  'DOID:0112094',
#  'DOID:0112095',
#  'DOID:0112096',
#  'DOID:0112097',
#  'DOID:0112098',
#  'DOID:0112099',
#  'DOID:0112101',
#  'DOID:0112102',
#  'DOID:0112103',
#  'DOID:0112104',
#  'DOID:0112105',
#  'DOID:0112106',
#  'DOID:0112107',
#  'DOID:0112108',
#  'DOID:0112109',
#  'DOID:0112110',
#  'DOID:0112111',
#  'DOID:0112112',
#  'DOID:0112113',
#  'DOID:0112114',
#  'DOID:0112115',
#  'DOID:0112116',
#  'DOID:0112117',
#  'DOID:0112118',
#  'DOID:0112119',
#  'DOID:0112120',
#  'DOID:0112121',
#  'DOID:0112122',
#  'DOID:0112123',
#  'DOID:0112125',
#  'DOID:0112126',
#  'DOID:0112127',
#  'DOID:0112128',
#  'DOID:0112129',
#  'DOID:0112130',
#  'DOID:0112131',
#  'DOID:0112132',
#  'DOID:0112133',
#  'DOID:0112134',
#  'DOID:0112135',
#  'DOID:0112136',
#  'DOID:0112137',
#  'DOID:0112138',
#  'DOID:0112139',
#  'DOID:0112140',
#  'DOID:0112141',
#  'DOID:0112142',
#  'DOID:0112143',
#  'DOID:0112144',
#  'DOID:0112145',
#  'DOID:0112146',
#  'DOID:0112147',
#  'DOID:0112148',
#  'DOID:0112149',
#  'DOID:0112150',
#  'DOID:0112151',
#  'DOID:0112152',
#  'DOID:0112153',
#  'DOID:0112154',
#  'DOID:0112155',
#  'DOID:0112156',
#  'DOID:0112157',
#  'DOID:0112158',
#  'DOID:0112159',
#  'DOID:0112160',
#  'DOID:0112161',
#  'DOID:0112162',
#  'DOID:0112163',
#  'DOID:0112164',
#  'DOID:0112165',
#  'DOID:0112166',
#  'DOID:0112167',
#  'DOID:0112168',
#  'DOID:0112169',
#  'DOID:0112170',
#  'DOID:0112171',
#  'DOID:0112172',
#  'DOID:0112173',
#  'DOID:0112174',
#  'DOID:0112175',
#  'DOID:0112176',
#  'DOID:0112177',
#  'DOID:0112178',
#  'DOID:0112179',
#  'DOID:0112180',
#  'DOID:0112181',
#  'DOID:0112182',
#  'DOID:0112183',
#  'DOID:0112184',
#  'DOID:0112185',
#  'DOID:0112186',
#  'DOID:0112187',
#  'DOID:0112188',
#  'DOID:0112189',
#  'DOID:0112190',
#  'DOID:0112191',
#  'DOID:0112192',
#  'DOID:0112193',
#  'DOID:0112194',
#  'DOID:0112195',
#  'DOID:0112196',
#  'DOID:0112201',
#  'DOID:0112202',
#  'DOID:0112203',
#  'DOID:0112204',
#  'DOID:0112205',
#  'DOID:0112206',
#  'DOID:0112207',
#  'DOID:0112208',
#  'DOID:0112209',
#  'DOID:0112210',
#  'DOID:0112211',
#  'DOID:0112212',
#  'DOID:0112213',
#  'DOID:0112214',
#  'DOID:0112215',
#  'DOID:0112216',
#  'DOID:0112217',
#  'DOID:0112218',
#  'DOID:0112219',
#  'DOID:0112220',
#  'DOID:0112221',
#  'DOID:0112222',
#  'DOID:0112223',
#  'DOID:0112224',
#  'DOID:0112225',
#  ...]

# %%
pd.DataFrame(msdf_mondo.df['object_id'].str.split(':').apply(lambda x: x[0] )).value_counts()
# Out:
# object_id
# UMLS         16622
# DOID          9814
# Orphanet      9783
# OMIM          9301
# SCTID         9048
# MESH          8155
# NCIT          6880
# ICD10CM       1206
# OMIMPS         532
# ICD10WHO        18
# MedDRA          12
# MEDGEN           2
# dtype: int64

# %%
print_prefixes(msdf_mondo.df)
# Out:
# subject_prefixes:
#  0    MONDO
# Name: subject_id, dtype: object
#            object_prefixes:
#  0           SCTID
# 1        Orphanet
# 2            NCIT
# 3            DOID
# 4            UMLS
# 5            MESH
# 11         OMIMPS
# 52        ICD10CM
# 169          OMIM
# 602        MedDRA
# 650      ICD10WHO
# 25327      MEDGEN
# Name: object_id, dtype: object
#            predicate_ids:
#  0        skos:exactMatch
# 26109    skos:broadMatch
# Name: predicate_id, dtype: object

# %%
# %%time
# msdf_mondo.df[msdf_mondo.df['object_id'].str.contains('ICD')]
# "ICD10CM", "MONDO"
# msdf_mondo.df = msdf_mondo.df[(condition_1 & condition_2) | (condition_3 & condition_4)]
# msdf_mondo.df['object_label'] = msdf_mondo.df['object_id'].apply(lambda x: oi.label(x))

msdf_mondo.df['object_label'] = msdf_mondo.df['object_id'].apply(lambda x: oi.label(x))
msdf_mondo.df.head()
# Out:
# CPU times: user 1min 9s, sys: 4.63 s, total: 1min 14s
# Wall time: 1min 14s
#       subject_id        subject_label     predicate_id        object_id  \
# 0  MONDO:0000001  disease or disorder  skos:exactMatch   SCTID:64572001
# 1  MONDO:0000001  disease or disorder  skos:exactMatch  Orphanet:377788
# 2  MONDO:0000001  disease or disorder  skos:exactMatch       NCIT:C2991
# 3  MONDO:0000001  disease or disorder  skos:exactMatch           DOID:4
# 4  MONDO:0000001  disease or disorder  skos:exactMatch    UMLS:C0012634
#
#         mapping_justification         object_label
# 0  semapv:UnspecifiedMatching                 None
# 1  semapv:UnspecifiedMatching                 None
# 2  semapv:UnspecifiedMatching  Disease or Disorder
# 3  semapv:UnspecifiedMatching              disease
# 4  semapv:UnspecifiedMatching                 None

# %%
condition_1 = msdf_mondo.df['subject_id'].str.contains("MONDO")
condition_2 = msdf_mondo.df['object_id'].str.contains("ICD10CM")
condition_3 = msdf_mondo.df['object_id'].str.contains('|'.join((["OMIM","OMIMPS"])))
condition_4 = msdf_mondo.df['object_id'].str.contains("Orphanet")
condition_5 = msdf_mondo.df['object_id'].str.contains("DOID")
condition_6 = msdf_mondo.df['object_id'].str.contains("NCIT")

mondo_icd_df = msdf_mondo.df[condition_1 & condition_2]
mondo_omim_df = msdf_mondo.df[condition_1 & condition_3]
mondo_ordo_df = msdf_mondo.df[condition_1 & condition_4]
mondo_doid_df = msdf_mondo.df[condition_1 & condition_5]
mondo_ncit_df = msdf_mondo.df[condition_1 & condition_6]

mondo_icd_df.head()
mondo_omim_df.head()
mondo_ordo_df.head()
mondo_doid_df.head()
mondo_ncit_df.head()
# Out:
#        subject_id                 subject_label     predicate_id  \
# 2   MONDO:0000001           disease or disorder  skos:exactMatch
# 10  MONDO:0000004  adrenocortical insufficiency  skos:exactMatch
# 17  MONDO:0000022            nocturnal enuresis  skos:exactMatch
# 48  MONDO:0000087                polymicrogyria  skos:exactMatch
# 51  MONDO:0000088            precocious puberty  skos:exactMatch
#
#        object_id       mapping_justification                  object_label
# 2     NCIT:C2991  semapv:UnspecifiedMatching           Disease or Disorder
# 10   NCIT:C26691  semapv:UnspecifiedMatching  Adrenocortical Insufficiency
# 17  NCIT:C118172  semapv:UnspecifiedMatching            Nocturnal Enuresis
# 48  NCIT:C116936  semapv:UnspecifiedMatching                Polymicrogyria
# 51   NCIT:C79704  semapv:UnspecifiedMatching            Precocious Puberty

# %%
print_prefixes(msdf_lex.df)
# Out:
# subject_prefixes:
#  0             DOID
# 98290      ICD10CM
# 115072    ICD10WHO
# 118862       MONDO
# 176282        NCIT
# Name: subject_id, dtype: object
#            object_prefixes:
#  0        MONDO
# 7         NCIT
# 10    ICD10WHO
# 17        DOID
# 35     ICD10CM
# Name: object_id, dtype: object
#            predicate_ids:
#  0       skos:exactMatch
# 6       skos:broadMatch
# 12      skos:closeMatch
# 158    skos:narrowMatch
# Name: predicate_id, dtype: object

# %% [markdown]
# ### Flipping subject_id and object_id if MONDO not subject_id prefix
#
# **Predicate impact**
#
# - skos:closeMatch <=> skos:relatedMatch
# - skos:narrowMatch < => skos:broadMatch

# %%
condition_1 = msdf_lex.df['subject_id'].str.contains("MONDO")
# condition_2 = msdf_lex.df['object_id'].str.contains("ICD10CM")
# condition_3 = msdf_lex.df['object_id'].str.contains('|'.join((["OMIM","OMIMPS"])))
# condition_4 = msdf_lex.df['object_id'].str.contains('|'.join((["ORDO","Orphanet"])))
# condition_5 = msdf_lex.df['object_id'].str.contains("DOID")
# condition_6 = msdf_lex.df['object_id'].str.contains("NCIT")
condition_mondo_obj = msdf_lex.df['object_id'].str.contains("MONDO")

non_mondo_subjects_df =  pd.DataFrame(msdf_lex.df[(~condition_1 & condition_mondo_obj)])
mondo_subjects_df = pd.DataFrame(msdf_lex.df[(condition_1 & ~condition_mondo_obj)])
print(len(mondo_subjects_df))
non_mondo_subjects_df.head()
# Out:
# 8231
#      subject_id subject_label     predicate_id      object_id  object_label  \
# 0  DOID:0001816  angiosarcoma  skos:exactMatch  MONDO:0016982  angiosarcoma
# 1  DOID:0001816  angiosarcoma  skos:exactMatch  MONDO:0016982  angiosarcoma
# 2  DOID:0001816  angiosarcoma  skos:exactMatch  MONDO:0016982  angiosarcoma
# 3  DOID:0001816  angiosarcoma  skos:exactMatch  MONDO:0016982  angiosarcoma
# 4  DOID:0001816  angiosarcoma  skos:exactMatch  MONDO:0016982  angiosarcoma
#
#     mapping_justification mapping_tool  confidence  subject_match_field  \
# 0  semapv:LexicalMatching       oaklib    0.941176        oio:hasDbXref
# 1  semapv:LexicalMatching       oaklib    0.849779           rdfs:label
# 2  semapv:LexicalMatching       oaklib    0.800000           rdfs:label
# 3  semapv:LexicalMatching       oaklib    0.800000           rdfs:label
# 4  semapv:LexicalMatching       oaklib    0.800000  oio:hasExactSynonym
#
#     object_match_field     match_string subject_preprocessing  \
# 0        oio:hasDbXref      icdo:9120/3
# 1           rdfs:label     angiosarcoma
# 2  oio:hasExactSynonym     angiosarcoma
# 3  oio:hasExactSynonym     angiosarcoma
# 4  oio:hasExactSynonym  hemangiosarcoma
#
#                   object_preprocessing
# 0
# 1
# 2
# 3  semapv:RegularExpressionReplacement
# 4

# %%
desired_sequence = ['subject_id', 'subject_label', 'object_id',
        'predicate_id','object_label', 'mapping_justification', 'mapping_tool', 'confidence',
        'subject_match_field', 'object_match_field', 'match_string']

new_subjects_df = non_mondo_subjects_df.rename(columns={
    'subject_id':'object_id', 
    'subject_label':'object_label',
    'object_id':'subject_id', 
    'object_label':'subject_label',
    'subject_match_field': 'object_match_field',
    'object_match_field': 'subject_match_field'
    
})


new_subjects_df = new_subjects_df[desired_sequence]
new_subjects_df["predicate_id"] = new_subjects_df["predicate_id"].apply(lambda x: flip_predicate(x))
print(len(new_subjects_df))
new_subjects_df.head()
# Out:
# 71567
#       subject_id subject_label     object_id     predicate_id  object_label  \
# 0  MONDO:0016982  angiosarcoma  DOID:0001816  skos:exactMatch  angiosarcoma
# 1  MONDO:0016982  angiosarcoma  DOID:0001816  skos:exactMatch  angiosarcoma
# 2  MONDO:0016982  angiosarcoma  DOID:0001816  skos:exactMatch  angiosarcoma
# 3  MONDO:0016982  angiosarcoma  DOID:0001816  skos:exactMatch  angiosarcoma
# 4  MONDO:0016982  angiosarcoma  DOID:0001816  skos:exactMatch  angiosarcoma
#
#     mapping_justification mapping_tool  confidence  subject_match_field  \
# 0  semapv:LexicalMatching       oaklib    0.941176        oio:hasDbXref
# 1  semapv:LexicalMatching       oaklib    0.849779           rdfs:label
# 2  semapv:LexicalMatching       oaklib    0.800000  oio:hasExactSynonym
# 3  semapv:LexicalMatching       oaklib    0.800000  oio:hasExactSynonym
# 4  semapv:LexicalMatching       oaklib    0.800000  oio:hasExactSynonym
#
#     object_match_field     match_string
# 0        oio:hasDbXref      icdo:9120/3
# 1           rdfs:label     angiosarcoma
# 2           rdfs:label     angiosarcoma
# 3           rdfs:label     angiosarcoma
# 4  oio:hasExactSynonym  hemangiosarcoma

# %% [markdown]
# ### Combine dfs where subject_id prefix is MONDO

# %%
lex_df = pd.concat([mondo_subjects_df,new_subjects_df], ignore_index=True)
print(len(lex_df))

lex_df.head()
# Out:
# 79798
#       subject_id                 subject_label      predicate_id  \
# 0  MONDO:0000001           disease or disorder   skos:exactMatch
# 1  MONDO:0000001           disease or disorder   skos:exactMatch
# 2  MONDO:0000004  adrenocortical insufficiency  skos:narrowMatch
# 3  MONDO:0000004  adrenocortical insufficiency  skos:narrowMatch
# 4  MONDO:0000004  adrenocortical insufficiency   skos:exactMatch
#
#         object_id                        object_label   mapping_justification  \
# 0     NCIT:C25457                           Condition  semapv:LexicalMatching
# 1    NCIT:C156809                   Medical Condition  semapv:LexicalMatching
# 2  ICD10CM:E27.49  Other adrenocortical insufficiency  semapv:LexicalMatching
# 3  ICD10CM:E27.49  Other adrenocortical insufficiency  semapv:LexicalMatching
# 4    NCIT:C113211                    Hypocortisolemia  semapv:LexicalMatching
#
#   mapping_tool  confidence  subject_match_field   object_match_field  \
# 0       oaklib         0.8  oio:hasExactSynonym           rdfs:label
# 1       oaklib         0.8  oio:hasExactSynonym           rdfs:label
# 2       oaklib         0.8           rdfs:label  oio:hasBroadSynonym
# 3       oaklib         0.8  oio:hasExactSynonym  oio:hasBroadSynonym
# 4       oaklib         0.8  oio:hasExactSynonym           rdfs:label
#
#                    match_string subject_preprocessing  \
# 0                     condition
# 1             medical condition
# 2  adrenocortical insufficiency
# 3  adrenocortical insufficiency
# 4              hypocortisolemia
#
#                   object_preprocessing
# 0
# 1
# 2  semapv:RegularExpressionReplacement
# 3  semapv:RegularExpressionReplacement
# 4

# %%
# msdf_lex.df[msdf_lex.df['object_id'].str.contains('ICD')]
condition_1 = lex_df['subject_id'].str.contains("MONDO")
condition_2 = lex_df['object_id'].str.contains("ICD10CM")
condition_3 = lex_df['object_id'].str.contains('|'.join((["OMIM","OMIMPS"])))
condition_4 = lex_df['object_id'].str.contains("Orphanet")
condition_5 = lex_df['object_id'].str.contains("DOID")
condition_6 = lex_df['object_id'].str.contains("NCIT")


mondo_icd_lex_df = lex_df[(condition_1 & condition_2)]
mondo_omim_lex_df = lex_df[(condition_1 & condition_3)]
mondo_ordo_lex_df = lex_df[(condition_1 & condition_4)]
mondo_doid_lex_df = lex_df[(condition_1 & condition_5)]
mondo_ncit_lex_df = lex_df[(condition_1 & condition_6)]

mondo_icd_lex_df.head()
mondo_omim_lex_df.head()
mondo_ordo_lex_df.head()
mondo_doid_lex_df.head()
mondo_ncit_lex_df.head()
# Out:
#       subject_id                 subject_label     predicate_id     object_id  \
# 0  MONDO:0000001           disease or disorder  skos:exactMatch   NCIT:C25457
# 1  MONDO:0000001           disease or disorder  skos:exactMatch  NCIT:C156809
# 4  MONDO:0000004  adrenocortical insufficiency  skos:exactMatch  NCIT:C113211
# 5  MONDO:0000159  bone marrow failure syndrome  skos:exactMatch  NCIT:C165614
# 6  MONDO:0000328             hyperphosphatemia  skos:exactMatch  NCIT:C113750
#
#                    object_label   mapping_justification mapping_tool  \
# 0                     Condition  semapv:LexicalMatching       oaklib
# 1             Medical Condition  semapv:LexicalMatching       oaklib
# 4              Hypocortisolemia  semapv:LexicalMatching       oaklib
# 5  Bone Marrow Failure Syndrome  semapv:LexicalMatching       oaklib
# 6             Hyperphosphatemia  semapv:LexicalMatching       oaklib
#
#    confidence  subject_match_field object_match_field  \
# 0    0.800000  oio:hasExactSynonym         rdfs:label
# 1    0.800000  oio:hasExactSynonym         rdfs:label
# 4    0.800000  oio:hasExactSynonym         rdfs:label
# 5    0.849779           rdfs:label         rdfs:label
# 6    0.849779           rdfs:label         rdfs:label
#
#                    match_string subject_preprocessing object_preprocessing
# 0                     condition
# 1             medical condition
# 4              hypocortisolemia
# 5  bone marrow failure syndrome
# 6             hyperphosphatemia

# %%
# %%time
# comparison_ms_diff = compare_dataframes(msdf_mondo.df, msdf_lex.df)
# comparison_df = comparison_ms_diff.combined_dataframe
# comparison_df['comment'] = comparison_df['comment'].str.replace('UNIQUE_1', "MONDO_MAPPINGS")
# comparison_df['comment'] = comparison_df['comment'].str.replace('UNIQUE_2', "LEXMATCH")
# comparison_df.head()

# Comparisons
icd_comparison_df = compare_and_comment_df(mondo_icd_df, mondo_icd_lex_df)
omim_comparison_df = compare_and_comment_df(mondo_omim_df, mondo_omim_lex_df)
ordo_comparison_df = compare_and_comment_df(mondo_ordo_df, mondo_ordo_lex_df)
doid_comparison_df = compare_and_comment_df(mondo_doid_df, mondo_doid_lex_df)
ncit_comparison_df = compare_and_comment_df(mondo_ncit_df, mondo_ncit_lex_df)
# Out:
# CPU times: user 56 s, sys: 182 ms, total: 56.2 s
# Wall time: 56.2 s

# %%
icd_comparison_df
omim_comparison_df
ordo_comparison_df
doid_comparison_df
ncit_comparison_df
# Out:
#           subject_id                              subject_label  \
# 71188  MONDO:0700051                    liver abscess (disease)
# 14797  MONDO:0005154                             liver disorder
# 8982   MONDO:0003277                     malignant ear neoplasm
# 15585  MONDO:0005401                           colonic neoplasm
# 19702  MONDO:0006777                               hairy tongue
# ...              ...                                        ...
# 1917   MONDO:0011178  infantile convulsions and choreoathetosis
# 44666  MONDO:0013282             alpha 1-antitrypsin deficiency
# 3160   MONDO:0013282             alpha 1-antitrypsin deficiency
# 37378  MONDO:0011266                  myotonic dystrophy type 2
# 1920   MONDO:0011266                  myotonic dystrophy type 2
#
#           predicate_id     object_id       mapping_justification  \
# 71188  skos:exactMatch   NCIT:C99089  semapv:UnspecifiedMatching
# 14797  skos:exactMatch    NCIT:C3196  semapv:UnspecifiedMatching
# 8982   skos:exactMatch    NCIT:C9337  semapv:UnspecifiedMatching
# 15585  skos:exactMatch    NCIT:C2953  semapv:UnspecifiedMatching
# 19702  skos:exactMatch   NCIT:C35075  semapv:UnspecifiedMatching
# ...                ...           ...                         ...
# 1917   skos:closeMatch  NCIT:C126650      semapv:LexicalMatching
# 44666  skos:exactMatch   NCIT:C84397  semapv:UnspecifiedMatching
# 3160   skos:closeMatch   NCIT:C84397      semapv:LexicalMatching
# 37378  skos:exactMatch   NCIT:C84680  semapv:UnspecifiedMatching
# 1920   skos:closeMatch   NCIT:C84680      semapv:LexicalMatching
#
#                                             object_label         comment  \
# 71188                                      Liver Abscess  MONDO_MAPPINGS
# 14797          Liver and Intrahepatic Bile Duct Disorder  MONDO_MAPPINGS
# 8982                              Malignant Ear Neoplasm  MONDO_MAPPINGS
# 15585                                     Colon Neoplasm  MONDO_MAPPINGS
# 19702                                       Hairy Tongue  MONDO_MAPPINGS
# ...                                                  ...             ...
# 1917   Infantile Convulsions and Paroxysmal Choreoath...  COMMON_TO_BOTH
# 44666                     Alpha-1 Antitrypsin Deficiency  COMMON_TO_BOTH
# 3160                      Alpha-1 Antitrypsin Deficiency  COMMON_TO_BOTH
# 37378                             Dystrophia Myotonica 2  COMMON_TO_BOTH
# 1920                              Dystrophia Myotonica 2  COMMON_TO_BOTH
#
#       mapping_tool  confidence    subject_match_field object_match_field  \
# 71188          NaN         NaN                    NaN                NaN
# 14797          NaN         NaN                    NaN                NaN
# 8982           NaN         NaN                    NaN                NaN
# 15585          NaN         NaN                    NaN                NaN
# 19702          NaN         NaN                    NaN                NaN
# ...            ...         ...                    ...                ...
# 1917        oaklib         NaN  oio:hasRelatedSynonym         rdfs:label
# 44666          NaN         NaN                    NaN                NaN
# 3160        oaklib         NaN  oio:hasRelatedSynonym         rdfs:label
# 37378          NaN         NaN                    NaN                NaN
# 1920        oaklib         NaN  oio:hasRelatedSynonym         rdfs:label
#
#                                             match_string  \
# 71188                                                NaN
# 14797                                                NaN
# 8982                                                 NaN
# 15585                                                NaN
# 19702                                                NaN
# ...                                                  ...
# 1917   infantile convulsions and paroxysmal choreoath...
# 44666                                                NaN
# 3160                      alpha-1 antitrypsin deficiency
# 37378                                                NaN
# 1920                              dystrophia myotonica 2
#
#       subject_preprocessing object_preprocessing
# 71188                   NaN                  NaN
# 14797                   NaN                  NaN
# 8982                    NaN                  NaN
# 15585                   NaN                  NaN
# 19702                   NaN                  NaN
# ...                     ...                  ...
# 1917
# 44666                   NaN                  NaN
# 3160
# 37378                   NaN                  NaN
# 1920
#
# [14422 rows x 14 columns]

# %%
ncit_comparison_df['comment'].drop_duplicates()
# Out:
# 71188    MONDO_MAPPINGS
# 6719           LEXMATCH
# 33408    COMMON_TO_BOTH
# Name: comment, dtype: object

# %% [markdown]
# ### Split into unmapped dataframes

# %%
unmapped_icd_df = get_unmapped_df(icd_comparison_df)
unmapped_omim_df = get_unmapped_df(omim_comparison_df)
unmapped_ordo_df = get_unmapped_df(ordo_comparison_df)
unmapped_doid_df = get_unmapped_df(doid_comparison_df)
unmapped_ncit_df = get_unmapped_df(ncit_comparison_df)

unmapped_icd_df.head()
# Out:
#           subject_id                        subject_label      predicate_id  \
# 76528  MONDO:0018896  thrombotic thrombocytopenic purpura   skos:exactMatch
# 1313   MONDO:0007885           Legg-Calve-Perthes disease  skos:narrowMatch
# 72775  MONDO:0004272         urinary bladder tuberculosis   skos:exactMatch
# 75645  MONDO:0024643                  myocardial disorder   skos:exactMatch
# 73330  MONDO:0024954              larva migrans, visceral   skos:closeMatch
#
#             object_id   mapping_justification  \
# 76528  ICD10CM:M31.19  semapv:LexicalMatching
# 1313    ICD10CM:M91.8  semapv:LexicalMatching
# 72775  ICD10CM:A18.12  semapv:LexicalMatching
# 75645   ICD10CM:I51.5  semapv:LexicalMatching
# 73330   ICD10CM:B83.0  semapv:LexicalMatching
#
#                                            object_label   comment  \
# 76528                  Other thrombotic microangiopathy  LEXMATCH
# 1313   Other juvenile osteochondrosis of hip and pelvis  LEXMATCH
# 72775                           Tuberculosis of bladder  LEXMATCH
# 75645                           Myocardial degeneration  LEXMATCH
# 73330                            Visceral larva migrans  LEXMATCH
#
#       mapping_tool  confidence    subject_match_field   object_match_field  \
# 76528       oaklib         0.8             rdfs:label  oio:hasExactSynonym
# 1313        oaklib         0.8    oio:hasExactSynonym  oio:hasBroadSynonym
# 72775       oaklib         0.8    oio:hasExactSynonym           rdfs:label
# 75645       oaklib         0.8    oio:hasExactSynonym  oio:hasExactSynonym
# 73330       oaklib         NaN  oio:hasRelatedSynonym           rdfs:label
#
#                                      match_string subject_preprocessing  \
# 76528         thrombotic thrombocytopenic purpura                   NaN
# 1313   juvenile osteochondrosis of hip and pelvis
# 72775                     tuberculosis of bladder                   NaN
# 75645                          myocardial disease                   NaN
# 73330                      visceral larva migrans                   NaN
#
#                       object_preprocessing
# 76528                                  NaN
# 1313   semapv:RegularExpressionReplacement
# 72775                                  NaN
# 75645                                  NaN
# 73330                                  NaN

# %%
print_prefixes(unmapped_ncit_df)
# Out:
# subject_prefixes:
#  7856    MONDO
# Name: subject_id, dtype: object
#            object_prefixes:
#  7856    NCIT
# Name: object_id, dtype: object
#            predicate_ids:
#  7856     skos:closeMatch
# 972      skos:exactMatch
# 79662    skos:broadMatch
# Name: predicate_id, dtype: object

# %%
# Let reviewers check if this makes sense or no.
export_unmatched_exact(unmapped_icd_df, "LEXMATCH", "unmapped_icd_lex.tsv")
export_unmatched_exact(unmapped_omim_df, "LEXMATCH", "unmapped_omim_lex.tsv")
export_unmatched_exact(unmapped_ordo_df, "LEXMATCH", "unmapped_ordo_lex.tsv")
export_unmatched_exact(unmapped_doid_df, "LEXMATCH", "unmapped_doid_lex.tsv")
export_unmatched_exact(unmapped_ncit_df, "LEXMATCH", "unmapped_ncit_lex.tsv")
# Out:
# /var/folders/j5/bzs7jjf12j998fm88l0ssg740000gp/T/ipykernel_9123/2993860202.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predicate_id'] = df['predicate_id'].apply(lambda x: mondo_codes[x] if x in mondo_codes else x)
# /var/folders/j5/bzs7jjf12j998fm88l0ssg740000gp/T/ipykernel_9123/2993860202.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predicate_id'] = df['predicate_id'].apply(lambda x: mondo_codes[x] if x in mondo_codes else x)
# /var/folders/j5/bzs7jjf12j998fm88l0ssg740000gp/T/ipykernel_9123/2993860202.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predicate_id'] = df['predicate_id'].apply(lambda x: mondo_codes[x] if x in mondo_codes else x)
#          subject_id                        subject_label  \
# 0                ID                                  NaN
# 972   MONDO:0006292               malignant mesothelioma
# 980   MONDO:0006363  peritoneal multicystic mesothelioma
# 7216  MONDO:0018881             myelodysplastic syndrome
# 7236  MONDO:0018989         recurrent acute pancreatitis
#
#               predicate_id           object_id   mapping_justification  \
# 0     A oboInOwl:hasDbXref  >A oboInOwl:source                     NaN
# 972     MONDO:equivalentTo         NCIT:C27926  semapv:LexicalMatching
# 980     MONDO:equivalentTo          NCIT:C3765  semapv:LexicalMatching
# 7216    MONDO:equivalentTo          NCIT:C8648  semapv:LexicalMatching
# 7236    MONDO:equivalentTo        NCIT:C184324  semapv:LexicalMatching
#
#                                   object_label   comment mapping_tool  \
# 0                        >A sssom:object_label       NaN          NaN
# 972    Asbestos-Related Malignant Mesothelioma  LEXMATCH       oaklib
# 980                   Multicystic Mesothelioma  LEXMATCH       oaklib
# 7216  Myelodysplastic Syndrome, Unclassifiable  LEXMATCH       oaklib
# 7236              Recurrent Acute Pancreatitis  LEXMATCH       oaklib
#
#       confidence  subject_match_field object_match_field  \
# 0            NaN                  NaN                NaN
# 972     0.800000  oio:hasExactSynonym         rdfs:label
# 980     0.800000  oio:hasExactSynonym         rdfs:label
# 7216    0.800000  oio:hasExactSynonym         rdfs:label
# 7236    0.849779           rdfs:label         rdfs:label
#
#                                   match_string subject_preprocessing  \
# 0                                          NaN                   NaN
# 972    asbestos-related malignant mesothelioma
# 980                   multicystic mesothelioma
# 7216  myelodysplastic syndrome, unclassifiable
# 7236              recurrent acute pancreatitis
#
#      object_preprocessing
# 0                     NaN
# 972
# 980
# 7216
# 7236

# %%
# Inspect why these are missing from SSSOM mappings
export_unmatched_exact(unmapped_icd_df, "MONDO_MAPPINGS", "unmapped_icd_mondo.tsv")
export_unmatched_exact(unmapped_omim_df, "MONDO_MAPPINGS", "unmapped_omim_mondo.tsv")
export_unmatched_exact(unmapped_ordo_df, "MONDO_MAPPINGS", "unmapped_ordo_mondo.tsv")
export_unmatched_exact(unmapped_doid_df, "MONDO_MAPPINGS", "unmapped_doid_mondo.tsv")
export_unmatched_exact(unmapped_ncit_df, "MONDO_MAPPINGS", "unmapped_ncit_mondo.tsv")
# Out:
# /var/folders/j5/bzs7jjf12j998fm88l0ssg740000gp/T/ipykernel_9123/2993860202.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predicate_id'] = df['predicate_id'].apply(lambda x: mondo_codes[x] if x in mondo_codes else x)
# /var/folders/j5/bzs7jjf12j998fm88l0ssg740000gp/T/ipykernel_9123/2993860202.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predicate_id'] = df['predicate_id'].apply(lambda x: mondo_codes[x] if x in mondo_codes else x)
# /var/folders/j5/bzs7jjf12j998fm88l0ssg740000gp/T/ipykernel_9123/2993860202.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predicate_id'] = df['predicate_id'].apply(lambda x: mondo_codes[x] if x in mondo_codes else x)
# /var/folders/j5/bzs7jjf12j998fm88l0ssg740000gp/T/ipykernel_9123/2993860202.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predicate_id'] = df['predicate_id'].apply(lambda x: mondo_codes[x] if x in mondo_codes else x)
#           subject_id                   subject_label          predicate_id  \
# 0                 ID                             NaN  A oboInOwl:hasDbXref
# 71188  MONDO:0700051         liver abscess (disease)    MONDO:equivalentTo
# 14797  MONDO:0005154                  liver disorder    MONDO:equivalentTo
# 19702  MONDO:0006777                    hairy tongue    MONDO:equivalentTo
# 6149   MONDO:0002327  intracranial cavernous angioma    MONDO:equivalentTo
#
#                 object_id       mapping_justification  \
# 0      >A oboInOwl:source                         NaN
# 71188         NCIT:C99089  semapv:UnspecifiedMatching
# 14797          NCIT:C3196  semapv:UnspecifiedMatching
# 19702         NCIT:C35075  semapv:UnspecifiedMatching
# 6149           NCIT:C5432  semapv:UnspecifiedMatching
#
#                                     object_label         comment mapping_tool  \
# 0                          >A sssom:object_label             NaN          NaN
# 71188                              Liver Abscess  MONDO_MAPPINGS          NaN
# 14797  Liver and Intrahepatic Bile Duct Disorder  MONDO_MAPPINGS          NaN
# 19702                               Hairy Tongue  MONDO_MAPPINGS          NaN
# 6149           Intracranial Cavernous Hemangioma  MONDO_MAPPINGS          NaN
#
#        confidence subject_match_field object_match_field match_string  \
# 0             NaN                 NaN                NaN          NaN
# 71188         NaN                 NaN                NaN          NaN
# 14797         NaN                 NaN                NaN          NaN
# 19702         NaN                 NaN                NaN          NaN
# 6149          NaN                 NaN                NaN          NaN
#
#       subject_preprocessing object_preprocessing
# 0                       NaN                  NaN
# 71188                   NaN                  NaN
# 14797                   NaN                  NaN
# 19702                   NaN                  NaN
# 6149                    NaN                  NaN

# %%
# # Add distances
# # Add Levenshtein distance [ 0: Perfect match]
# add_distance(unmapped_mondo_exact, "levenshtein_dist", textdistance.levenshtein.distance)
# # Add Jaccard Index [ 0: Perfect match]
# add_distance(unmapped_mondo_exact, "jaccard_index", textdistance.jaccard.distance)
# # Add Monge-Elkan Distance [ 0: Perfect match]
# add_distance(unmapped_mondo_exact, "monge_elkan", textdistance.monge_elkan.distance)
# unmapped_mondo_exact.to_csv(join(dir_name, "unmapped_mondo_exact.tsv"), sep='\t', index = False)
# unmapped_mondo_exact.head()

# %%
# combined_msdf_icd = make_msdf(unmapped_icd_df, msdf_lex.prefix_map, msdf_lex.metadata)
# combined_msdf_omim = make_msdf(unmapped_omim_df, msdf_lex.prefix_map, msdf_lex.metadata)
# combined_msdf_ordo = make_msdf(unmapped_ordo_df, msdf_lex.prefix_map, msdf_lex.metadata)
# combined_msdf_doid = make_msdf(unmapped_doid_df, msdf_lex.prefix_map, msdf_lex.metadata)
# combined_msdf_ncit = make_msdf(unmapped_ncit_df, msdf_lex.prefix_map, msdf_lex.metadata)

combined_df = pd.concat(
    [unmapped_icd_df, unmapped_omim_df, unmapped_ordo_df, unmapped_doid_df, unmapped_ncit_df]
)

combined_msdf = make_msdf(combined_df, msdf_lex.prefix_map, msdf_lex.metadata)
combined_msdf.df.head()
# Out:
#           subject_id                        subject_label      predicate_id  \
# 76528  MONDO:0018896  thrombotic thrombocytopenic purpura   skos:exactMatch
# 1313   MONDO:0007885           Legg-Calve-Perthes disease  skos:narrowMatch
# 72775  MONDO:0004272         urinary bladder tuberculosis   skos:exactMatch
# 75645  MONDO:0024643                  myocardial disorder   skos:exactMatch
# 73330  MONDO:0024954              larva migrans, visceral   skos:closeMatch
#
#             object_id   mapping_justification  \
# 76528  ICD10CM:M31.19  semapv:LexicalMatching
# 1313    ICD10CM:M91.8  semapv:LexicalMatching
# 72775  ICD10CM:A18.12  semapv:LexicalMatching
# 75645   ICD10CM:I51.5  semapv:LexicalMatching
# 73330   ICD10CM:B83.0  semapv:LexicalMatching
#
#                                            object_label   comment  \
# 76528                  Other thrombotic microangiopathy  LEXMATCH
# 1313   Other juvenile osteochondrosis of hip and pelvis  LEXMATCH
# 72775                           Tuberculosis of bladder  LEXMATCH
# 75645                           Myocardial degeneration  LEXMATCH
# 73330                            Visceral larva migrans  LEXMATCH
#
#       mapping_tool  confidence    subject_match_field   object_match_field  \
# 76528       oaklib         0.8             rdfs:label  oio:hasExactSynonym
# 1313        oaklib         0.8    oio:hasExactSynonym  oio:hasBroadSynonym
# 72775       oaklib         0.8    oio:hasExactSynonym           rdfs:label
# 75645       oaklib         0.8    oio:hasExactSynonym  oio:hasExactSynonym
# 73330       oaklib         NaN  oio:hasRelatedSynonym           rdfs:label
#
#                                      match_string subject_preprocessing  \
# 76528         thrombotic thrombocytopenic purpura                   NaN
# 1313   juvenile osteochondrosis of hip and pelvis
# 72775                     tuberculosis of bladder                   NaN
# 75645                          myocardial disease                   NaN
# 73330                      visceral larva migrans                   NaN
#
#                       object_preprocessing
# 76528                                  NaN
# 1313   semapv:RegularExpressionReplacement
# 72775                                  NaN
# 75645                                  NaN
# 73330                                  NaN

# %%
# %%time
df_dict = split_dataframe(combined_msdf)
# Out:
# /opt/anaconda3/envs/mondo-ingest/lib/python3.9/site-packages/sssom/parsers.py:864: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   subject_prefixes = set(msdf.df[SUBJECT_ID].str.split(":", 1, expand=True)[0])
# /opt/anaconda3/envs/mondo-ingest/lib/python3.9/site-packages/sssom/parsers.py:865: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   object_prefixes = set(msdf.df[OBJECT_ID].str.split(":", 1, expand=True)[0])
# WARNING:root:Not adding mondo_narrowmatch_ncit because there is a missing prefix (MONDO, NCIT), or no matches (0 matches found)
# WARNING:root:Not adding mondo_closematch_omim because there is a missing prefix (MONDO, OMIM), or no matches (0 matches found)
# WARNING:root:Not adding mondo_exactmatch_omim because there is a missing prefix (MONDO, OMIM), or no matches (9301 matches found)
# WARNING:root:Not adding mondo_broadmatch_omim because there is a missing prefix (MONDO, OMIM), or no matches (0 matches found)
# WARNING:root:Not adding mondo_narrowmatch_omim because there is a missing prefix (MONDO, OMIM), or no matches (0 matches found)
# WARNING:root:Not adding mondo_closematch_omimps because there is a missing prefix (MONDO, OMIMPS), or no matches (0 matches found)
# WARNING:root:Not adding mondo_exactmatch_omimps because there is a missing prefix (MONDO, OMIMPS), or no matches (532 matches found)
# WARNING:root:Not adding mondo_broadmatch_omimps because there is a missing prefix (MONDO, OMIMPS), or no matches (0 matches found)
# WARNING:root:Not adding mondo_narrowmatch_omimps because there is a missing prefix (MONDO, OMIMPS), or no matches (0 matches found)
# WARNING:root:Not adding mondo_closematch_orphanet because there is a missing prefix (MONDO, Orphanet), or no matches (0 matches found)
# WARNING:root:Not adding mondo_exactmatch_orphanet because there is a missing prefix (MONDO, Orphanet), or no matches (9780 matches found)
# WARNING:root:Not adding mondo_broadmatch_orphanet because there is a missing prefix (MONDO, Orphanet), or no matches (1 matches found)
# WARNING:root:Not adding mondo_narrowmatch_orphanet because there is a missing prefix (MONDO, Orphanet), or no matches (0 matches found)
# CPU times: user 9.14 s, sys: 57.7 ms, total: 9.2 s
# Wall time: 11.7 s

# %%
df_dict.keys()
# Out:
# dict_keys(['mondo_closematch_ncit', 'mondo_exactmatch_ncit', 'mondo_broadmatch_ncit', 'mondo_closematch_doid', 'mondo_exactmatch_doid', 'mondo_broadmatch_doid', 'mondo_narrowmatch_doid', 'mondo_closematch_icd10cm', 'mondo_exactmatch_icd10cm', 'mondo_broadmatch_icd10cm', 'mondo_narrowmatch_icd10cm'])

# %%
# mondo_icd_list = [x for x in list(df_dict.keys()) if 'mondo' in x and "icd10" in x]
# mondo_icd_list

# %%
for match in df_dict.keys():
    fn = match + ".tsv"
    df_dict[match].df.to_csv(join(dir_name,fn), sep='\t', index = False)

# %%
df_dict['mondo_exactmatch_icd10cm'].df
# Out:
#          subject_id                                      subject_label  \
# 0     MONDO:0000022                                 nocturnal enuresis
# 1     MONDO:0000078                          acrocephalopolysyndactyly
# 2     MONDO:0000129                                  glutaric aciduria
# 3     MONDO:0000129                                  glutaric aciduria
# 4     MONDO:0000153                transposition of the great arteries
# ...             ...                                                ...
# 2301  MONDO:0700081              newborn respiratory distress syndrome
# 2302  MONDO:0700081              newborn respiratory distress syndrome
# 2303  MONDO:0800026  central hypoventilation syndrome, congenital, ...
# 2304  MONDO:0800177                                          frostbite
# 2305  MONDO:0800177                                          frostbite
#
#          predicate_id        object_id  \
# 0     skos:exactMatch   ICD10CM:N39.44
# 1     skos:exactMatch    ICD10CM:Q87.0
# 2     skos:exactMatch    ICD10CM:E72.3
# 3     skos:exactMatch    ICD10CM:E72.3
# 4     skos:exactMatch    ICD10CM:Q20.3
# ...               ...              ...
# 2301  skos:exactMatch    ICD10CM:P22.0
# 2302  skos:exactMatch    ICD10CM:P22.0
# 2303  skos:exactMatch   ICD10CM:G47.35
# 2304  skos:exactMatch  ICD10CM:T33-T34
# 2305  skos:exactMatch  ICD10CM:T33-T34
#
#                                            object_label  \
# 0                                    Nocturnal enuresis
# 1     Congenital malformation syndromes predominantl...
# 2      Disorders of lysine and hydroxylysine metabolism
# 3      Disorders of lysine and hydroxylysine metabolism
# 4              Discordant ventriculoarterial connection
# ...                                                 ...
# 2301           Respiratory distress syndrome of newborn
# 2302           Respiratory distress syndrome of newborn
# 2303  Congenital central alveolar hypoventilation sy...
# 2304                                Frostbite (T33-T34)
# 2305                                Frostbite (T33-T34)
#
#        mapping_justification mapping_tool  confidence  subject_match_field  \
# 0     semapv:LexicalMatching       oaklib    0.849779           rdfs:label
# 1     semapv:LexicalMatching       oaklib    0.800000           rdfs:label
# 2     semapv:LexicalMatching       oaklib    0.800000  oio:hasExactSynonym
# 3     semapv:LexicalMatching       oaklib    0.800000           rdfs:label
# 4     semapv:LexicalMatching       oaklib    0.800000  oio:hasExactSynonym
# ...                      ...          ...         ...                  ...
# 2301  semapv:LexicalMatching       oaklib    0.800000  oio:hasExactSynonym
# 2302  semapv:LexicalMatching       oaklib    0.800000  oio:hasExactSynonym
# 2303  semapv:LexicalMatching       oaklib    0.800000  oio:hasExactSynonym
# 2304  semapv:LexicalMatching       oaklib    0.849779           rdfs:label
# 2305  semapv:LexicalMatching       oaklib    0.800000           rdfs:label
#
#        object_match_field                                       match_string  \
# 0              rdfs:label                                 nocturnal enuresis
# 1     oio:hasExactSynonym                          acrocephalopolysyndactyly
# 2     oio:hasExactSynonym                                  glutaric aciduria
# 3     oio:hasExactSynonym                                  glutaric aciduria
# 4     oio:hasExactSynonym                     transposition of great vessels
# ...                   ...                                                ...
# 2301  oio:hasExactSynonym                           hyaline membrane disease
# 2302           rdfs:label           respiratory distress syndrome of newborn
# 2303           rdfs:label  congenital central alveolar hypoventilation sy...
# 2304           rdfs:label                                          frostbite
# 2305  oio:hasExactSynonym                                          frostbite
#
#        comment
# 0     LEXMATCH
# 1     LEXMATCH
# 2     LEXMATCH
# 3     LEXMATCH
# 4     LEXMATCH
# ...        ...
# 2301  LEXMATCH
# 2302  LEXMATCH
# 2303  LEXMATCH
# 2304  LEXMATCH
# 2305  LEXMATCH
#
# [2306 rows x 12 columns]
